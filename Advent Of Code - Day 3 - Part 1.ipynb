# %%
import re

# %%
example_string = "xmul(2,4)&mul[3,7]!^don't()_mul(5,5)+mul(32,64](mul(11,8)undo()?mul(8,5))"

# %%
input_file = "AdventOfCode_Day3_input.txt"
# open input file
with open(input_file, "r") as text_file:
    file = text_file.read()

# %%
print(type(file))
#print(file)
# Out:
# <class 'str'>

# %%
currupted_string = file

# %%
mul_words =[]
# loop to find the first instance of )
first_index = 0

for last_index, last_letter in enumerate(currupted_string):
    
    # if ) 
    if last_letter == ")":
        # section everything from last section to end this section)
        section = currupted_string[first_index:last_index+1]
        print(section)
        # work backwards to get the first m or is it the second :/
        reverse_section = section[::-1]
        print(reverse_section)
        
        for m_index, m_letter in enumerate(reverse_section):
            if m_letter == "m":
                # calc start to m
                reverse_section = reverse_section[:m_index+1]
                print(reverse_section)
                # reverse it again
                section = reverse_section[::-1]
                print("final: ", section)

                # check section starts with mul
                # check that section contains a comma
                # checl that ( and ) appears once
                if section.startswith("mul(") and "," in section and section.count("(") == 1 and section.count(")") == 1:
                    mul_words.append(section)
                    first_index = last_index+1
                    break
        print("")
# Out:
# [why()
# )(yhw[
#
# [why()what()
# )(tahw)(yhw[
#
# [why()what()]:!*<)
# )<*!:])(tahw)(yhw[
#
# [why()what()]:!*<)~mul(929,350)
# )053,929(lum~)<*!:])(tahw)(yhw[
# )053,929(lum
# final:  mul(929,350)
#
# ({)
# ){(
#
# ({)when()
# )(nehw){(
#
# ({)when()@mul(878,389)
# )983,878(lum@)(nehw){(
# )983,878(lum
# final:  mul(878,389)
#
# }$!? mul(786,950)
# )059,687(lum ?!$}
# )059,687(lum
# final:  mul(786,950)
#
# ~when()
# )(nehw~
#
# ~when();[(#mul(808,160)
# )061,808(lum#([;)(nehw~
# )061,808(lum
# final:  mul(808,160)
#
# mul(659,500)
# )005,956(lum
# )005,956(lum
# final:  mul(659,500)
#
# &+?*mul(659,863)
# )368,956(lum*?+&
# )368,956(lum
# final:  mul(659,863)
#
# ~~&:;,>do()
# )(od>,;:&~~
#
# ~~&:;,>do()(%@from()
# )(morf@%()(od>,;:&~~
# )(m
# final:  m()
#
# ~~&:;,>do()(%@from()^!how()
# )(woh!^)(morf@%()(od>,;:&~~
# )(woh!^)(m
# final:  m()^!how()
#
# ~~&:;,>do()(%@from()^!how()how()
# )(woh)(woh!^)(morf@%()(od>,;:&~~
# )(woh)(woh!^)(m
# final:  m()^!how()how()
#
# ~~&:;,>do()(%@from()^!how()how()'@mul(281,23)
# )32,182(lum@')(woh)(woh!^)(morf@%()(od>,;:&~~
# )32,182(lum
# final:  mul(281,23)
#
# -^~mul(473,263)
# )362,374(lum~^-
# )362,374(lum
# final:  mul(473,263)
#
# }&!?when()
# )(nehw?!&}
#
# }&!?when()~mul(208,697)
# )796,802(lum~)(nehw?!&}
# )796,802(lum
# final:  mul(208,697)
#
# ?^)
# )^?
#
# ?^)from()
# )(morf)^?
# )(m
# final:  m()
#
# ?^)from()}who()
# )(ohw})(morf)^?
# )(ohw})(m
# final:  m()}who()
#
# ?^)from()}who()]-where()
# )(erehw-])(ohw})(morf)^?
# )(erehw-])(ohw})(m
# final:  m()}who()]-where()
#
# ?^)from()}who()]-where()mul(975,727)
# )727,579(lum)(erehw-])(ohw})(morf)^?
# )727,579(lum
# final:  mul(975,727)
#
# ?where()
# )(erehw?
#
# ?where()'who()
# )(ohw')(erehw?
#
# ?where()'who()&&]how()
# )(woh]&&)(ohw')(erehw?
#
# ?where()'who()&&]how()don't()
# )(t'nod)(woh]&&)(ohw')(erehw?
#
# ?where()'who()&&]how()don't()]',{how()
# )(woh{,'])(t'nod)(woh]&&)(ohw')(erehw?
#
# ?where()'who()&&]how()don't()]',{how())
# ))(woh{,'])(t'nod)(woh]&&)(ohw')(erehw?
#
# ?where()'who()&&]how()don't()]',{how())mul(862,420)
# )024,268(lum))(woh{,'])(t'nod)(woh]&&)(ohw')(erehw?
# )024,268(lum
# final:  mul(862,420)
#
# ,mul(505,346)
# )643,505(lum,
# )643,505(lum
# final:  mul(505,346)
#
# mul(150,525)
# )525,051(lum
# )525,051(lum
# final:  mul(150,525)
#
# @'~[-,]^who()
# )(ohw^],-[~'@
#
# @'~[-,]^who()mul(842,702)
# )207,248(lum)(ohw^],-[~'@
# )207,248(lum
# final:  mul(842,702)
#
# # where()
# )(erehw #
#
# # where()who()
# )(ohw)(erehw #
#
# # where()who()/*/@-select()
# )(tceles-@/*/)(ohw)(erehw #
#
# # where()who()/*/@-select()don't()
# )(t'nod)(tceles-@/*/)(ohw)(erehw #
#
# # where()who()/*/@-select()don't()what()
# )(tahw)(t'nod)(tceles-@/*/)(ohw)(erehw #
#
# # where()who()/*/@-select()don't()what():when()
# )(nehw:)(tahw)(t'nod)(tceles-@/*/)(ohw)(erehw #
#
# # where()who()/*/@-select()don't()what():when()when()
# )(nehw)(nehw:)(tahw)(t'nod)(tceles-@/*/)(ohw)(erehw #
#
# # where()who()/*/@-select()don't()what():when()when()how()
# )(woh)(nehw)(nehw:)(tahw)(t'nod)(tceles-@/*/)(ohw)(erehw #
#
# # where()who()/*/@-select()don't()what():when()when()how()[what()
# )(tahw[)(woh)(nehw)(nehw:)(tahw)(t'nod)(tceles-@/*/)(ohw)(erehw #
#
# # where()who()/*/@-select()don't()what():when()when()how()[what()%(mul(669,360)
# )063,966(lum(%)(tahw[)(woh)(nehw)(nehw:)(tahw)(t'nod)(tceles-@/*/)(ohw)(erehw #
# )063,966(lum
# final:  mul(669,360)
#
# >@!+&what()
# )(tahw&+!@>
#
# >@!+&what() ^%mul(285,288)
# )882,582(lum%^ )(tahw&+!@>
# )882,582(lum
# final:  mul(285,288)
#
# mul(778,743)
# )347,877(lum
# )347,877(lum
# final:  mul(778,743)
#
# why()
# )(yhw
#
# why()!+?((^;mul(725,987)
# )789,527(lum;^((?+!)(yhw
# )789,527(lum
# final:  mul(725,987)
#
# *where(491,873)
# )378,194(erehw*
#
# *where(491,873)+don't()
# )(t'nod+)378,194(erehw*
#
# *where(491,873)+don't():how()
# )(woh:)(t'nod+)378,194(erehw*
#
# *where(491,873)+don't():how()what()
# )(tahw)(woh:)(t'nod+)378,194(erehw*
#
# *where(491,873)+don't():how()what()'(mul(757,125)
# )521,757(lum(')(tahw)(woh:)(t'nod+)378,194(erehw*
# )521,757(lum
# final:  mul(757,125)
#
# what()
# )(tahw
#
# what()}/where()
# )(erehw/})(tahw
#
# what()}/where()why()
# )(yhw)(erehw/})(tahw
#
# what()}/where()why()]@don't()
# )(t'nod@])(yhw)(erehw/})(tahw
#
# what()}/where()why()]@don't()select()
# )(tceles)(t'nod@])(yhw)(erehw/})(tahw
#
# what()}/where()why()]@don't()select()}(/select()
# )(tceles/(})(tceles)(t'nod@])(yhw)(erehw/})(tahw
#
# what()}/where()why()]@don't()select()}(/select()$$when()
# )(nehw$$)(tceles/(})(tceles)(t'nod@])(yhw)(erehw/})(tahw
#
# what()}/where()why()]@don't()select()}(/select()$$when()']mul(494,390)
# )093,494(lum]')(nehw$$)(tceles/(})(tceles)(t'nod@])(yhw)(erehw/})(tahw
# )093,494(lum
# final:  mul(494,390)
#
# }-who()
# )(ohw-}
#
# }-who()+mul(182,852)
# )258,281(lum+)(ohw-}
# )258,281(lum
# final:  mul(182,852)
#
# when()
# )(nehw
#
# when()#*^mul(144,423)
# )324,441(lum^*#)(nehw
# )324,441(lum
# final:  mul(144,423)
#
# )
# )
#
# )mul(250,580)
# )085,052(lum)
# )085,052(lum
# final:  mul(250,580)
#
# {what()
# )(tahw{
#
# {what()%%where()
# )(erehw%%)(tahw{
#
# {what()%%where()* mul(870,438)
# )834,078(lum *)(erehw%%)(tahw{
# )834,078(lum
# final:  mul(870,438)
#
# from(431,933)
# )339,134(morf
# )339,134(m
# final:  m(431,933)
#
# from(431,933)' when()
# )(nehw ')339,134(morf
# )(nehw ')339,134(m
# final:  m(431,933)' when()
#
# from(431,933)' when()mul(965,381)
# )183,569(lum)(nehw ')339,134(morf
# )183,569(lum
# final:  mul(965,381)
#
# why()
# )(yhw
#
# why()how()
# )(woh)(yhw
#
# why()how()@where()
# )(erehw@)(woh)(yhw
#
# why()how()@where()<what()
# )(tahw<)(erehw@)(woh)(yhw
#
# why()how()@where()<what()what()
# )(tahw)(tahw<)(erehw@)(woh)(yhw
#
# why()how()@where()<what()what()$@&mul(124,500)
# )005,421(lum&@$)(tahw)(tahw<)(erehw@)(woh)(yhw
# )005,421(lum
# final:  mul(124,500)
#
# (<mul(307,602)
# )206,703(lum<(
# )206,703(lum
# final:  mul(307,602)
#
# !mul(294,55)
# )55,492(lum!
# )55,492(lum
# final:  mul(294,55)
#
# when()
# )(nehw
#
# when()*mul(466,143)
# )341,664(lum*)(nehw
# )341,664(lum
# final:  mul(466,143)
#
# $when()
# )(nehw$
#
# $when()+@why()
# )(yhw@+)(nehw$
#
# $when()+@why()-'what(60,159)
# )951,06(tahw'-)(yhw@+)(nehw$
#
# $when()+@why()-'what(60,159)@{mul(594,617)
# )716,495(lum{@)951,06(tahw'-)(yhw@+)(nehw$
# )716,495(lum
# final:  mul(594,617)
#
# /%who()
# )(ohw%/
#
# /%who()'why()
# )(yhw')(ohw%/
#
# /%who()'why()!]who()
# )(ohw]!)(yhw')(ohw%/
#
# /%who()'why()!]who()+mul(590,187)
# )781,095(lum+)(ohw]!)(yhw')(ohw%/
# )781,095(lum
# final:  mul(590,187)
#
# $,,why()
# )(yhw,,$
#
# $,,why()<>?from()
# )(morf?><)(yhw,,$
# )(m
# final:  m()
#
# $,,why()<>?from()mul(817,13)
# )31,718(lum)(morf?><)(yhw,,$
# )31,718(lum
# final:  mul(817,13)
#
# $;what(648,988)
# )889,846(tahw;$
#
# $;what(648,988)mul(25,13)
# )31,52(lum)889,846(tahw;$
# )31,52(lum
# final:  mul(25,13)
#
# [(do()
# )(od([
#
# [(do()why()
# )(yhw)(od([
#
# [(do()why()when(916,672)
# )276,619(nehw)(yhw)(od([
#
# [(do()why()when(916,672){?what()
# )(tahw?{)276,619(nehw)(yhw)(od([
#
# [(do()why()when(916,672){?what()*'what()
# )(tahw'*)(tahw?{)276,619(nehw)(yhw)(od([
#
# [(do()why()when(916,672){?what()*'what())
# ))(tahw'*)(tahw?{)276,619(nehw)(yhw)(od([
#
# [(do()why()when(916,672){?what()*'what())mul(469,12)
# )21,964(lum))(tahw'*)(tahw?{)276,619(nehw)(yhw)(od([
# )21,964(lum
# final:  mul(469,12)
#
# &!([[how()
# )(woh[[(!&
#
# &!([[how()where()
# )(erehw)(woh[[(!&
#
# &!([[how()where()mul(619,597)
# )795,916(lum)(erehw)(woh[[(!&
# )795,916(lum
# final:  mul(619,597)
#
# +]where()
# )(erehw]+
#
# +]where()&{%)
# )%{&)(erehw]+
#
# +]where()&{%)[+mul(734,721)
# )127,437(lum+[)%{&)(erehw]+
# )127,437(lum
# final:  mul(734,721)
#
# ^:&%how()
# )(woh%&:^
#
# ^:&%how()[where()
# )(erehw[)(woh%&:^
#
# ^:&%how()[where()who()
# )(ohw)(erehw[)(woh%&:^
#
# ^:&%how()[where()who();mul(725,524)
# )425,527(lum;)(ohw)(erehw[)(woh%&:^
# )425,527(lum
# final:  mul(725,524)
#
# )
# )
#
# )mul(389,895)
# )598,983(lum)
# )598,983(lum
# final:  mul(389,895)
#
# mul(166,39)
# )93,661(lum
# )93,661(lum
# final:  mul(166,39)
#
#  )
# )
#
#  )select()
# )(tceles)
#
#  )select():mul(655,784)
# )487,556(lum:)(tceles)
# )487,556(lum
# final:  mul(655,784)
#
# where()
# )(erehw
#
# where()])
# )])(erehw
#
# where()]),]who()
# )(ohw],)])(erehw
#
# where()]),]who()what()
# )(tahw)(ohw],)])(erehw
#
# where()]),]who()what()]:who()
# )(ohw:])(tahw)(ohw],)])(erehw
#
# where()]),]who()what()]:who()mul(353,573)
# )375,353(lum)(ohw:])(tahw)(ohw],)])(erehw
# )375,353(lum
# final:  mul(353,573)
#
# >~%^< #what()
# )(tahw# <^%~>
#
# >~%^< #what()}mul(522,78)
# )87,225(lum})(tahw# <^%~>
# )87,225(lum
# final:  mul(522,78)
#
# *where()
# )(erehw*
#
# *where()when()
# )(nehw)(erehw*
#
# *where()when()^$+&&mul(236,646)
# )646,632(lum&&+$^)(nehw)(erehw*
# )646,632(lum
# final:  mul(236,646)
#
# !-who()
# )(ohw-!
#
# !-who()$>from()
# )(morf>$)(ohw-!
# )(m
# final:  m()
#
# !-who()$>from()?%mul(376,189)
# )981,673(lum%?)(morf>$)(ohw-!
# )981,673(lum
# final:  mul(376,189)
#
#  $''@$ who()
# )(ohw $@''$
#
#  $''@$ who()mul(300,957)
# )759,003(lum)(ohw $@''$
# )759,003(lum
# final:  mul(300,957)
#
# [mul(83,888)
# )888,38(lum[
# )888,38(lum
# final:  mul(83,888)
#
# mul(107,58)
# )85,701(lum
# )85,701(lum
# final:  mul(107,58)
#
# '*<mul(220,142)
# )241,022(lum<*'
# )241,022(lum
# final:  mul(220,142)
#
# mul(526,112)
# )211,625(lum
# )211,625(lum
# final:  mul(526,112)
#
# $$*who()
# )(ohw*$$
#
# $$*who()-{,' )
# ) ',{-)(ohw*$$
#
# $$*who()-{,' )mul(23,943)
# )349,32(lum) ',{-)(ohw*$$
# )349,32(lum
# final:  mul(23,943)
#
# $who()
# )(ohw$
#
# $who()^mul(338,718)
# )817,833(lum^)(ohw$
# )817,833(lum
# final:  mul(338,718)
#
# (/'-mul(371,364)
# )463,173(lum-'/(
# )463,173(lum
# final:  mul(371,364)
#
# from()
# )(morf
# )(m
# final:  m()
#
# from()&)
# )&)(morf
# )&)(m
# final:  m()&)
#
# from()&)<}why()
# )(yhw}<)&)(morf
# )(yhw}<)&)(m
# final:  m()&)<}why()
#
# from()&)<}why()^ mul(856,727)
# )727,658(lum ^)(yhw}<)&)(morf
# )727,658(lum
# final:  mul(856,727)
#
# from()
# )(morf
# )(m
# final:  m()
#
# from()#/mul(360,371)
# )173,063(lum/#)(morf
# )173,063(lum
# final:  mul(360,371)
#
# *;/$?#mul(664,647)
# )746,466(lum#?$/;*
# )746,466(lum
# final:  mul(664,647)
#
# @)
# )@
#
# @)how()
# )(woh)@
#
# @)how()[,+%)
# )%+,[)(woh)@
#
# @)how()[,+%)mul(607,641)
# )146,706(lum)%+,[)(woh)@
# )146,706(lum
# final:  mul(607,641)
#
#  *how()
# )(woh*
#
#  *how()@mul(395,603)
# )306,593(lum@)(woh*
# )306,593(lum
# final:  mul(395,603)
#
# who()
# )(ohw
#
# who()+-~^what()
# )(tahw^~-+)(ohw
#
# who()+-~^what()mul(909,984)
# )489,909(lum)(tahw^~-+)(ohw
# )489,909(lum
# final:  mul(909,984)
#
# from()
# )(morf
# )(m
# final:  m()
#
# from())
# ))(morf
# ))(m
# final:  m())
#
# from())select()
# )(tceles))(morf
# )(tceles))(m
# final:  m())select()
#
# from())select()what()
# )(tahw)(tceles))(morf
# )(tahw)(tceles))(m
# final:  m())select()what()
#
# from())select()what()why()
# )(yhw)(tahw)(tceles))(morf
# )(yhw)(tahw)(tceles))(m
# final:  m())select()what()why()
#
# from())select()what()why()^: #,mul(271,246)
# )642,172(lum,# :^)(yhw)(tahw)(tceles))(morf
# )642,172(lum
# final:  mul(271,246)
#
# from()
# )(morf
# )(m
# final:  m()
#
# from()$$why()
# )(yhw$$)(morf
# )(yhw$$)(m
# final:  m()$$why()
#
# from()$$why()^!why()
# )(yhw!^)(yhw$$)(morf
# )(yhw!^)(yhw$$)(m
# final:  m()$$why()^!why()
#
# from()$$why()^!why()]~^mul(627,532)
# )235,726(lum^~])(yhw!^)(yhw$$)(morf
# )235,726(lum
# final:  mul(627,532)
#
# ^(when()
# )(nehw(^
#
# ^(when()mul(229,147)
# )741,922(lum)(nehw(^
# )741,922(lum
# final:  mul(229,147)
#
# select()
# )(tceles
#
# select()+when()
# )(nehw+)(tceles
#
# select()+when()what()
# )(tahw)(nehw+)(tceles
#
# select()+when()what()&from()
# )(morf&)(tahw)(nehw+)(tceles
# )(m
# final:  m()
#
# select()+when()what()&from()$do()
# )(od$)(morf&)(tahw)(nehw+)(tceles
# )(od$)(m
# final:  m()$do()
#
# select()+when()what()&from()$do()how()
# )(woh)(od$)(morf&)(tahw)(nehw+)(tceles
# )(woh)(od$)(m
# final:  m()$do()how()
#
# select()+when()what()&from()$do()how()who()
# )(ohw)(woh)(od$)(morf&)(tahw)(nehw+)(tceles
# )(ohw)(woh)(od$)(m
# final:  m()$do()how()who()
#
# select()+when()what()&from()$do()how()who()#who()
# )(ohw#)(ohw)(woh)(od$)(morf&)(tahw)(nehw+)(tceles
# )(ohw#)(ohw)(woh)(od$)(m
# final:  m()$do()how()who()#who()
#
# select()+when()what()&from()$do()how()who()#who()mul(516,484)
# )484,615(lum)(ohw#)(ohw)(woh)(od$)(morf&)(tahw)(nehw+)(tceles
# )484,615(lum
# final:  mul(516,484)
#
# mul(897,791)
# )197,798(lum
# )197,798(lum
# final:  mul(897,791)
#
#  ,]mul(975,824)
# )428,579(lum],
# )428,579(lum
# final:  mul(975,824)
#
# from()
# )(morf
# )(m
# final:  m()
#
# from()mul(861,612)
# )216,168(lum)(morf
# )216,168(lum
# final:  mul(861,612)
#
# ;where()
# )(erehw;
#
# ;where()$why()
# )(yhw$)(erehw;
#
# ;where()$why()%&from()
# )(morf&%)(yhw$)(erehw;
# )(m
# final:  m()
#
# ;where()$why()%&from()%why()
# )(yhw%)(morf&%)(yhw$)(erehw;
# )(yhw%)(m
# final:  m()%why()
#
# ;where()$why()%&from()%why()when()
# )(nehw)(yhw%)(morf&%)(yhw$)(erehw;
# )(nehw)(yhw%)(m
# final:  m()%why()when()
#
# ;where()$why()%&from()%why()when()mul(467,971)
# )179,764(lum)(nehw)(yhw%)(morf&%)(yhw$)(erehw;
# )179,764(lum
# final:  mul(467,971)
#
# *^what()
# )(tahw^*
#
# *^what()%&$-%?mul(351,45)
# )54,153(lum?%-$&%)(tahw^*
# )54,153(lum
# final:  mul(351,45)
#
# /mul(404,604)
# )406,404(lum/
# )406,404(lum
# final:  mul(404,604)
#
# from(78,564)
# )465,87(morf
# )465,87(m
# final:  m(78,564)
#
# from(78,564)~:mul(821,895)
# )598,128(lum:~)465,87(morf
# )598,128(lum
# final:  mul(821,895)
#
# @*<(mul(108,809)
# )908,801(lum(<*@
# )908,801(lum
# final:  mul(108,809)
#
# why()
# )(yhw
#
# why(){^?how()
# )(woh?^{)(yhw
#
# why(){^?how()where()
# )(erehw)(woh?^{)(yhw
#
# why(){^?how()where()who()
# )(ohw)(erehw)(woh?^{)(yhw
#
# why(){^?how()where()who()%^mul(107,714)
# )417,701(lum^%)(ohw)(erehw)(woh?^{)(yhw
# )417,701(lum
# final:  mul(107,714)
#
# ';who()
# )(ohw;'
#
# ';who()'+:(*$mul(651,179)
# )971,156(lum$*(:+')(ohw;'
# )971,156(lum
# final:  mul(651,179)
#
# %&;mul(421,625)
# )526,124(lum;&%
# )526,124(lum
# final:  mul(421,625)
#
# !select(67,621)
# )126,76(tceles!
#
# !select(67,621)$-: +mul(190,973)
# )379,091(lum+ :-$)126,76(tceles!
# )379,091(lum
# final:  mul(190,973)
#
#  )
# )
#
#  )+'what()
# )(tahw'+)
#
#  )+'what()how()
# )(woh)(tahw'+)
#
#  )+'what()how()mul(90what()
# )(tahw09(lum)(woh)(tahw'+)
# )(tahw09(lum
# final:  mul(90what()
#
#  )+'what()how()mul(90what()mul(532,234)
# )432,235(lum)(tahw09(lum)(woh)(tahw'+)
# )432,235(lum
# final:  mul(532,234)
#
# ~**#?/:mul(178,924)
# )429,871(lum:/?#**~
# )429,871(lum
# final:  mul(178,924)
#
# <how()
# )(woh<
#
# <how():#where()
# )(erehw#:)(woh<
#
# <how():#where(),mul(258,345)
# )543,852(lum,)(erehw#:)(woh<
# )543,852(lum
# final:  mul(258,345)
#
# (when()
# )(nehw(
#
# (when())
# ))(nehw(
#
# (when())!select()
# )(tceles!))(nehw(
#
# (when())!select()}^,mul(590,995)
# )599,095(lum,^})(tceles!))(nehw(
# )599,095(lum
# final:  mul(590,995)
#
# mul(563,305)
# )503,365(lum
# )503,365(lum
# final:  mul(563,305)
#
# #)
# )#
#
# #)$?<['^what()
# )(tahw^'[<?$)#
#
# #)$?<['^what())
# ))(tahw^'[<?$)#
#
# #)$?<['^what())mul(539,574)
# )475,935(lum))(tahw^'[<?$)#
# )475,935(lum
# final:  mul(539,574)
#
# '#<&'$who()
# )(ohw$'&<#'
#
# '#<&'$who()#mul(493,590)
# )095,394(lum#)(ohw$'&<#'
# )095,394(lum
# final:  mul(493,590)
#
# $who()
# )(ohw$
#
# $who()what()
# )(tahw)(ohw$
#
# $who()what()mul(574,298)
# )892,475(lum)(tahw)(ohw$
# )892,475(lum
# final:  mul(574,298)
#
# who()
# )(ohw
#
# who()who()
# )(ohw)(ohw
#
# who()who()@:![mul(213,273)
# )372,312(lum[!:@)(ohw)(ohw
# )372,312(lum
# final:  mul(213,273)
#
# ,how()
# )(woh,
#
# ,how()$from()
# )(morf$)(woh,
# )(m
# final:  m()
#
# ,how()$from()who()
# )(ohw)(morf$)(woh,
# )(ohw)(m
# final:  m()who()
#
# ,how()$from()who()select()
# )(tceles)(ohw)(morf$)(woh,
# )(tceles)(ohw)(m
# final:  m()who()select()
#
# ,how()$from()who()select()why()
# )(yhw)(tceles)(ohw)(morf$)(woh,
# )(yhw)(tceles)(ohw)(m
# final:  m()who()select()why()
#
# ,how()$from()who()select()why(){;&mulfrom()
# )(morflum&;{)(yhw)(tceles)(ohw)(morf$)(woh,
# )(m
# final:  m()
# )(m
# final:  m()
# )(m
# final:  m()
#
# ,how()$from()who()select()why(){;&mulfrom()do()
# )(od)(morflum&;{)(yhw)(tceles)(ohw)(morf$)(woh,
# )(od)(m
# final:  m()do()
# )(od)(m
# final:  m()do()
# )(od)(m
# final:  m()do()
#
# ,how()$from()who()select()why(){;&mulfrom()do() &$%how()
# )(woh%$& )(od)(morflum&;{)(yhw)(tceles)(ohw)(morf$)(woh,
# )(woh%$& )(od)(m
# final:  m()do() &$%how()
# )(woh%$& )(od)(m
# final:  m()do() &$%how()
# )(woh%$& )(od)(m
# final:  m()do() &$%how()
#
# ,how()$from()who()select()why(){;&mulfrom()do() &$%how()[+mul(539,428)
# )824,935(lum+[)(woh%$& )(od)(morflum&;{)(yhw)(tceles)(ohw)(morf$)(woh,
# )824,935(lum
# final:  mul(539,428)
#
# ;mul(289,634)
# )436,982(lum;
# )436,982(lum
# final:  mul(289,634)
#
# mul(178,932)
# )239,871(lum
# )239,871(lum
# final:  mul(178,932)
#
# ,why()
# )(yhw,
#
# ,why()when()
# )(nehw)(yhw,
#
# ,why()when()what()
# )(tahw)(nehw)(yhw,
#
# ,why()when()what() ^+select()
# )(tceles+^ )(tahw)(nehw)(yhw,
#
# ,why()when()what() ^+select()>#mul(535,222)
# )222,535(lum#>)(tceles+^ )(tahw)(nehw)(yhw,
# )222,535(lum
# final:  mul(535,222)
#
# 'mul(370,487)
# )784,073(lum'
# )784,073(lum
# final:  mul(370,487)
#
# >{:::+)
# )+:::{>
#
# >{:::+);select()
# )(tceles;)+:::{>
#
# >{:::+);select()mul(228,11)
# )11,822(lum)(tceles;)+:::{>
# )11,822(lum
# final:  mul(228,11)
#
# mul(961,125)
# )521,169(lum
# )521,169(lum
# final:  mul(961,125)
#
# ^select()
# )(tceles^
#
# ^select()mul(489,332)
# )233,984(lum)(tceles^
# )233,984(lum
# final:  mul(489,332)
#
# +/!^#where()
# )(erehw#^!/+
#
# +/!^#where()select()
# )(tceles)(erehw#^!/+
#
# +/!^#where()select()mul(757,495)
# )594,757(lum)(tceles)(erehw#^!/+
# )594,757(lum
# final:  mul(757,495)
#
# *don't()
# )(t'nod*
#
# *don't();]who()
# )(ohw];)(t'nod*
#
# *don't();]who()how()
# )(woh)(ohw];)(t'nod*
#
# *don't();]who()how()mul(814,931)
# )139,418(lum)(woh)(ohw];)(t'nod*
# )139,418(lum
# final:  mul(814,931)
#
# ?)
# )?
#
# ?)how()
# )(woh)?
#
# ?)how()^^?$when()
# )(nehw$?^^)(woh)?
#
# ?)how()^^?$when()mul(669,252)
# )252,966(lum)(nehw$?^^)(woh)?
# )252,966(lum
# final:  mul(669,252)
#
# ,]mul(69,754)
# )457,96(lum],
# )457,96(lum
# final:  mul(69,754)
#
# when()
# )(nehw
#
# when(),@select()
# )(tceles@,)(nehw
#
# when(),@select()when()
# )(nehw)(tceles@,)(nehw
#
# when(),@select()when()^mul(316,878)
# )878,613(lum^)(nehw)(tceles@,)(nehw
# )878,613(lum
# final:  mul(316,878)
#
# how()
# )(woh
#
# how()']mul(772,418)
# )814,277(lum]')(woh
# )814,277(lum
# final:  mul(772,418)
#
# !}why()
# )(yhw}!
#
# !}why()(,who()
# )(ohw,()(yhw}!
#
# !}why()(,who()mul(186,499)
# )994,681(lum)(ohw,()(yhw}!
# )994,681(lum
# final:  mul(186,499)
#
# {^[where()
# )(erehw[^{
#
# {^[where()%$what()
# )(tahw$%)(erehw[^{
#
# {^[where()%$what() select()
# )(tceles )(tahw$%)(erehw[^{
#
# {^[where()%$what() select()from()
# )(morf)(tceles )(tahw$%)(erehw[^{
# )(m
# final:  m()
#
# {^[where()%$what() select()from()mul(711,645/^mul(517,805)
# )508,715(lum^/546,117(lum)(morf)(tceles )(tahw$%)(erehw[^{
# )508,715(lum
# final:  mul(517,805)
#
# &[why()
# )(yhw[&
#
# &[why()&~mul(970,867)
# )768,079(lum~&)(yhw[&
# )768,079(lum
# final:  mul(970,867)
#
# where()
# )(erehw
#
# where()>mul[% select()
# )(tceles %[lum>)(erehw
# )(tceles %[lum
# final:  mul[% select()
#
# where()>mul[% select()who()
# )(ohw)(tceles %[lum>)(erehw
# )(ohw)(tceles %[lum
# final:  mul[% select()who()
#
# where()>mul[% select()who()/what()
# )(tahw/)(ohw)(tceles %[lum>)(erehw
# )(tahw/)(ohw)(tceles %[lum
# final:  mul[% select()who()/what()
#
# where()>mul[% select()who()/what() select()
# )(tceles )(tahw/)(ohw)(tceles %[lum>)(erehw
# )(tceles )(tahw/)(ohw)(tceles %[lum
# final:  mul[% select()who()/what() select()
#
# where()>mul[% select()who()/what() select()?select()
# )(tceles?)(tceles )(tahw/)(ohw)(tceles %[lum>)(erehw
# )(tceles?)(tceles )(tahw/)(ohw)(tceles %[lum
# final:  mul[% select()who()/what() select()?select()
#
# where()>mul[% select()who()/what() select()?select()mul(739,456)
# )654,937(lum)(tceles?)(tceles )(tahw/)(ohw)(tceles %[lum>)(erehw
# )654,937(lum
# final:  mul(739,456)
#
# **mul(620,935)
# )539,026(lum**
# )539,026(lum
# final:  mul(620,935)
#
# -%,where()
# )(erehw,%-
#
# -%,where();,what()
# )(tahw,;)(erehw,%-
#
# -%,where();,what()how()
# )(woh)(tahw,;)(erehw,%-
#
# -%,where();,what()how() mul(715,502)
# )205,517(lum )(woh)(tahw,;)(erehw,%-
# )205,517(lum
# final:  mul(715,502)
#
# +when()
# )(nehw+
#
# +when()where()
# )(erehw)(nehw+
#
# +when()where()#>mul(635,908)
# )809,536(lum>#)(erehw)(nehw+
# )809,536(lum
# final:  mul(635,908)
#
# why()
# )(yhw
#
# why()what()
# )(tahw)(yhw
#
# why()what();:mul(30,139)
# )931,03(lum:;)(tahw)(yhw
# )931,03(lum
# final:  mul(30,139)
#
# <from()
# )(morf<
# )(m
# final:  m()
#
# <from()/%mul(832,717)
# )717,238(lum%/)(morf<
# )717,238(lum
# final:  mul(832,717)
#
# where()
# )(erehw
#
# where()!}mul(518,190)
# )091,815(lum}!)(erehw
# )091,815(lum
# final:  mul(518,190)
#
# mul(760,645)
# )546,067(lum
# )546,067(lum
# final:  mul(760,645)
#
# ,what()
# )(tahw,
#
# ,what()<how()
# )(woh<)(tahw,
#
# ,what()<how()+mul(835,464)
# )464,538(lum+)(woh<)(tahw,
# )464,538(lum
# final:  mul(835,464)
#
# !'}mul(929,827)
# )728,929(lum}'!
# )728,929(lum
# final:  mul(929,827)
#
# select()
# )(tceles
#
# select():,'mul(838,387)
# )783,838(lum',:)(tceles
# )783,838(lum
# final:  mul(838,387)
#
# when()
# )(nehw
#
# when()~why()
# )(yhw~)(nehw
#
# when()~why()what()
# )(tahw)(yhw~)(nehw
#
# when()~why()what()(from()
# )(morf()(tahw)(yhw~)(nehw
# )(m
# final:  m()
#
# when()~why()what()(from()#select()
# )(tceles#)(morf()(tahw)(yhw~)(nehw
# )(tceles#)(m
# final:  m()#select()
#
# when()~why()what()(from()#select()mul(147,945)
# )549,741(lum)(tceles#)(morf()(tahw)(yhw~)(nehw
# )549,741(lum
# final:  mul(147,945)
#
# how()
# )(woh
#
# how()+'[^]{&mul(325,147where()
# )(erehw741,523(lum&{]^['+)(woh
# )(erehw741,523(lum
# final:  mul(325,147where()
#
# how()+'[^]{&mul(325,147where()why()
# )(yhw)(erehw741,523(lum&{]^['+)(woh
# )(yhw)(erehw741,523(lum
# final:  mul(325,147where()why()
#
# how()+'[^]{&mul(325,147where()why();+^from(173,815)
# )518,371(morf^+;)(yhw)(erehw741,523(lum&{]^['+)(woh
# )518,371(m
# final:  m(173,815)
# )518,371(m
# final:  m(173,815)
#
# how()+'[^]{&mul(325,147where()why();+^from(173,815)who()
# )(ohw)518,371(morf^+;)(yhw)(erehw741,523(lum&{]^['+)(woh
# )(ohw)518,371(m
# final:  m(173,815)who()
# )(ohw)518,371(m
# final:  m(173,815)who()
#
# how()+'[^]{&mul(325,147where()why();+^from(173,815)who(): mul(689,161)
# )161,986(lum :)(ohw)518,371(morf^+;)(yhw)(erehw741,523(lum&{]^['+)(woh
# )161,986(lum
# final:  mul(689,161)
#
# },$&#{mul(214,950)
# )059,412(lum{#&$,}
# )059,412(lum
# final:  mul(214,950)
#
# select()
# )(tceles
#
# select()}why()
# )(yhw})(tceles
#
# select()}why()^*mul(165,90)
# )09,561(lum*^)(yhw})(tceles
# )09,561(lum
# final:  mul(165,90)
#
# @where()
# )(erehw@
#
# @where()?mul(996,995)
# )599,699(lum?)(erehw@
# )599,699(lum
# final:  mul(996,995)
#
# '<#&don't()
# )(t'nod&#<'
#
# '<#&don't()</why()
# )(yhw/<)(t'nod&#<'
#
# '<#&don't()</why()]how()
# )(woh])(yhw/<)(t'nod&#<'
#
# '<#&don't()</why()]how()~ '%;mul(347,352)
# )253,743(lum;%' ~)(woh])(yhw/<)(t'nod&#<'
# )253,743(lum
# final:  mul(347,352)
#
#
# [from()
# )(morf[
#
# )(m
# final:  m()
#
#
# [from()mul(564,902)
# )209,465(lum)(morf[
#
# )209,465(lum
# final:  mul(564,902)
#
# mul(515,489)
# )984,515(lum
# )984,515(lum
# final:  mul(515,489)
#
# !when()
# )(nehw!
#
# !when()mul*?*where()
# )(erehw*?*lum)(nehw!
# )(erehw*?*lum
# final:  mul*?*where()
#
# !when()mul*?*where()mul(676,277)
# )772,676(lum)(erehw*?*lum)(nehw!
# )772,676(lum
# final:  mul(676,277)
#
# mul(243,328)
# )823,342(lum
# )823,342(lum
# final:  mul(243,328)
#
# what()
# )(tahw
#
# what():/+'mul(845,930)
# )039,548(lum'+/:)(tahw
# )039,548(lum
# final:  mul(845,930)
#
# <{^&@why()
# )(yhw@&^{<
#
# <{^&@why()from(378,555)
# )555,873(morf)(yhw@&^{<
# )555,873(m
# final:  m(378,555)
#
# <{^&@why()from(378,555)>{/mul(696,341)
# )143,696(lum/{>)555,873(morf)(yhw@&^{<
# )143,696(lum
# final:  mul(696,341)
#
# $mul(178,75)
# )57,871(lum$
# )57,871(lum
# final:  mul(178,75)
#
# $,&/]>:why()
# )(yhw:>]/&,$
#
# $,&/]>:why()mul(531,586)
# )685,135(lum)(yhw:>]/&,$
# )685,135(lum
# final:  mul(531,586)
#
# ;;mul(639,746)
# )647,936(lum;;
# )647,936(lum
# final:  mul(639,746)
#
# ~select()
# )(tceles~
#
# ~select();/$mul(501,62)
# )26,105(lum$/;)(tceles~
# )26,105(lum
# final:  mul(501,62)
#
# ;]mul(796,439)
# )934,697(lum];
# )934,697(lum
# final:  mul(796,439)
#
# >*<%where()
# )(erehw%<*>
#
# >*<%where():~,*?mulfrom()
# )(morflum?*,~:)(erehw%<*>
# )(m
# final:  m()
# )(m
# final:  m()
#
# >*<%where():~,*?mulfrom()+}*do()
# )(od*}+)(morflum?*,~:)(erehw%<*>
# )(od*}+)(m
# final:  m()+}*do()
# )(od*}+)(m
# final:  m()+}*do()
#
# >*<%where():~,*?mulfrom()+}*do()mul(766,409)
# )904,667(lum)(od*}+)(morflum?*,~:)(erehw%<*>
# )904,667(lum
# final:  mul(766,409)
#
# {mul(418,953)
# )359,814(lum{
# )359,814(lum
# final:  mul(418,953)
#
# where()
# )(erehw
#
# where();#from()
# )(morf#;)(erehw
# )(m
# final:  m()
#
# where();#from()select()
# )(tceles)(morf#;)(erehw
# )(tceles)(m
# final:  m()select()
#
# where();#from()select()$&what(178,382)
# )283,871(tahw&$)(tceles)(morf#;)(erehw
# )283,871(tahw&$)(tceles)(m
# final:  m()select()$&what(178,382)
#
# where();#from()select()$&what(178,382)mul(435,11)
# )11,534(lum)283,871(tahw&$)(tceles)(morf#;)(erehw
# )11,534(lum
# final:  mul(435,11)
#
# }[mul(398,68!&-<@:<why()
# )(yhw<:@<-&!86,893(lum[}
# )(yhw<:@<-&!86,893(lum
# final:  mul(398,68!&-<@:<why()
#
# }[mul(398,68!&-<@:<why()where()
# )(erehw)(yhw<:@<-&!86,893(lum[}
# )(erehw)(yhw<:@<-&!86,893(lum
# final:  mul(398,68!&-<@:<why()where()
#
# }[mul(398,68!&-<@:<why()where()*'mul(756,293)
# )392,657(lum'*)(erehw)(yhw<:@<-&!86,893(lum[}
# )392,657(lum
# final:  mul(756,293)
#
# ^where()
# )(erehw^
#
# ^where()!&mul(598,25)
# )52,895(lum&!)(erehw^
# )52,895(lum
# final:  mul(598,25)
#
# do()
# )(od
#
# do()~mul(483,67)
# )76,384(lum~)(od
# )76,384(lum
# final:  mul(483,67)
#
# mul(116,813)
# )318,611(lum
# )318,611(lum
# final:  mul(116,813)
#
# )
# )
#
# )}*@don't()
# )(t'nod@*})
#
# )}*@don't()mul(807,2)
# )2,708(lum)(t'nod@*})
# )2,708(lum
# final:  mul(807,2)
#
# ;[-{<!!~@)
# )@~!!<{-[;
#
# ;[-{<!!~@)mul(982,63)
# )36,289(lum)@~!!<{-[;
# )36,289(lum
# final:  mul(982,63)
#
# how()
# )(woh
#
# how()/*;?[!mul(292,746)
# )647,292(lum![?;*/)(woh
# )647,292(lum
# final:  mul(292,746)
#
# where()
# )(erehw
#
# where()'!&*mul(20,251)
# )152,02(lum*&!')(erehw
# )152,02(lum
# final:  mul(20,251)
#
# mul(258,348)
# )843,852(lum
# )843,852(lum
# final:  mul(258,348)
#
# *mul(570,47)
# )74,075(lum*
# )74,075(lum
# final:  mul(570,47)
#
# what(720,953)
# )359,027(tahw
#
# what(720,953){}who()
# )(ohw}{)359,027(tahw
#
# what(720,953){}who())
# ))(ohw}{)359,027(tahw
#
# what(720,953){}who())#^:)
# ):^#))(ohw}{)359,027(tahw
#
# what(720,953){}who())#^:)mul(932,524)
# )425,239(lum):^#))(ohw}{)359,027(tahw
# )425,239(lum
# final:  mul(932,524)
#
# how()
# )(woh
#
# how()-mul(939,325)
# )523,939(lum-)(woh
# )523,939(lum
# final:  mul(939,325)
#
# !$mul(174,638)
# )836,471(lum$!
# )836,471(lum
# final:  mul(174,638)
#
# ~why(588,329)
# )923,885(yhw~
#
# ~why(588,329);mul(180,359)
# )953,081(lum;)923,885(yhw~
# )953,081(lum
# final:  mul(180,359)
#
# mul(627,164)
# )461,726(lum
# )461,726(lum
# final:  mul(627,164)
#
# mul(445,389)
# )983,544(lum
# )983,544(lum
# final:  mul(445,389)
#
# </why()
# )(yhw/<
#
# </why()[where()
# )(erehw[)(yhw/<
#
# </why()[where()mul(115,522)
# )225,511(lum)(erehw[)(yhw/<
# )225,511(lum
# final:  mul(115,522)
#
# mul(516,970)
# )079,615(lum
# )079,615(lum
# final:  mul(516,970)
#
# +mul(750,179)
# )971,057(lum+
# )971,057(lum
# final:  mul(750,179)
#
# mul(393,378)
# )873,393(lum
# )873,393(lum
# final:  mul(393,378)
#
# '/][[-mul(400,355)
# )553,004(lum-[[]/'
# )553,004(lum
# final:  mul(400,355)
#
# [-}+[mul}*%!:~'^mul(606,611)
# )116,606(lum^'~:!%*}lum[+}-[
# )116,606(lum
# final:  mul(606,611)
#
# -why()
# )(yhw-
#
# -why()--<(  mul(637,439>$mul(628,277)
# )772,826(lum$>934,736(lum  (<--)(yhw-
# )772,826(lum
# final:  mul(628,277)
#
# mul(570,862)
# )268,075(lum
# )268,075(lum
# final:  mul(570,862)
#
# >]what()
# )(tahw]>
#
# >]what()?<'$mul(624,957)
# )759,426(lum$'<?)(tahw]>
# )759,426(lum
# final:  mul(624,957)
#
# ^]mul(946,45)
# )54,649(lum]^
# )54,649(lum
# final:  mul(946,45)
#
# [~why()
# )(yhw~[
#
# [~why()[from()
# )(morf[)(yhw~[
# )(m
# final:  m()
#
# [~why()[from())
# ))(morf[)(yhw~[
# ))(m
# final:  m())
#
# [~why()[from()) ?do()
# )(od? ))(morf[)(yhw~[
# )(od? ))(m
# final:  m()) ?do()
#
# [~why()[from()) ?do()>how()
# )(woh>)(od? ))(morf[)(yhw~[
# )(woh>)(od? ))(m
# final:  m()) ?do()>how()
#
# [~why()[from()) ?do()>how(),{+}from()
# )(morf}+{,)(woh>)(od? ))(morf[)(yhw~[
# )(m
# final:  m()
# )(m
# final:  m()
#
# [~why()[from()) ?do()>how(),{+}from()mul(687,919)
# )919,786(lum)(morf}+{,)(woh>)(od? ))(morf[)(yhw~[
# )919,786(lum
# final:  mul(687,919)
#
# ]why()
# )(yhw]
#
# ]why()who()
# )(ohw)(yhw]
#
# ]why()who()who()
# )(ohw)(ohw)(yhw]
#
# ]why()who()who()how()
# )(woh)(ohw)(ohw)(yhw]
#
# ]why()who()who()how()<%mul(839,726)
# )627,938(lum%<)(woh)(ohw)(ohw)(yhw]
# )627,938(lum
# final:  mul(839,726)
#
# #*-'@>(~>mul(588,167)
# )761,885(lum>~(>@'-*#
# )761,885(lum
# final:  mul(588,167)
#
# @%@when()
# )(nehw@%@
#
# @%@when()why()
# )(yhw)(nehw@%@
#
# @%@when()why()when()
# )(nehw)(yhw)(nehw@%@
#
# @%@when()why()when() #mul(503,12)
# )21,305(lum# )(nehw)(yhw)(nehw@%@
# )21,305(lum
# final:  mul(503,12)
#
# select()
# )(tceles
#
# select() %!;[don't()
# )(t'nod[;!% )(tceles
#
# select() %!;[don't()when()
# )(nehw)(t'nod[;!% )(tceles
#
# select() %!;[don't()when(){-]%why()
# )(yhw%]-{)(nehw)(t'nod[;!% )(tceles
#
# select() %!;[don't()when(){-]%why()!%+:mul(55,105)
# )501,55(lum:+%!)(yhw%]-{)(nehw)(t'nod[;!% )(tceles
# )501,55(lum
# final:  mul(55,105)
#
# @what()
# )(tahw@
#
# @what())
# ))(tahw@
#
# @what())mul(349,994)
# )499,943(lum))(tahw@
# )499,943(lum
# final:  mul(349,994)
#
# }who()
# )(ohw}
#
# }who()where(424,307)
# )703,424(erehw)(ohw}
#
# }who()where(424,307)}from()
# )(morf})703,424(erehw)(ohw}
# )(m
# final:  m()
#
# }who()where(424,307)}from()what()
# )(tahw)(morf})703,424(erehw)(ohw}
# )(tahw)(m
# final:  m()what()
#
# }who()where(424,307)}from()what()mul(991,980)
# )089,199(lum)(tahw)(morf})703,424(erehw)(ohw}
# )089,199(lum
# final:  mul(991,980)
#
# mul(313,17)
# )71,313(lum
# )71,313(lum
# final:  mul(313,17)
#
# where()
# )(erehw
#
# where()*[+%from()
# )(morf%+[*)(erehw
# )(m
# final:  m()
#
# where()*[+%from()&how()
# )(woh&)(morf%+[*)(erehw
# )(woh&)(m
# final:  m()&how()
#
# where()*[+%from()&how()-;mul(118,53)
# )35,811(lum;-)(woh&)(morf%+[*)(erehw
# )35,811(lum
# final:  mul(118,53)
#
# ~<!why()
# )(yhw!<~
#
# ~<!why()from()
# )(morf)(yhw!<~
# )(m
# final:  m()
#
# ~<!why()from():mul(914,345'[~}mul(276,699)
# )996,672(lum}~['543,419(lum:)(morf)(yhw!<~
# )996,672(lum
# final:  mul(276,699)
#
# how()
# )(woh
#
# how()who()
# )(ohw)(woh
#
# how()who())
# ))(ohw)(woh
#
# how()who()):how()
# )(woh:))(ohw)(woh
#
# how()who()):how()mul(238,673)
# )376,832(lum)(woh:))(ohw)(woh
# )376,832(lum
# final:  mul(238,673)
#
# $:{}(~mul(840,690why()
# )(yhw096,048(lum~(}{:$
# )(yhw096,048(lum
# final:  mul(840,690why()
#
# $:{}(~mul(840,690why()from()
# )(morf)(yhw096,048(lum~(}{:$
# )(m
# final:  m()
# )(m
# final:  m()
#
# $:{}(~mul(840,690why()from()who()
# )(ohw)(morf)(yhw096,048(lum~(}{:$
# )(ohw)(m
# final:  m()who()
# )(ohw)(m
# final:  m()who()
#
# $:{}(~mul(840,690why()from()who(){>why()
# )(yhw>{)(ohw)(morf)(yhw096,048(lum~(}{:$
# )(yhw>{)(ohw)(m
# final:  m()who(){>why()
# )(yhw>{)(ohw)(m
# final:  m()who(){>why()
#
# $:{}(~mul(840,690why()from()who(){>why()^@from()
# )(morf@^)(yhw>{)(ohw)(morf)(yhw096,048(lum~(}{:$
# )(m
# final:  m()
# )(m
# final:  m()
# )(m
# final:  m()
#
# $:{}(~mul(840,690why()from()who(){>why()^@from()-mul(40,718)
# )817,04(lum-)(morf@^)(yhw>{)(ohw)(morf)(yhw096,048(lum~(}{:$
# )817,04(lum
# final:  mul(40,718)
#
# '&why()
# )(yhw&'
#
# '&why()mul(393,507)
# )705,393(lum)(yhw&'
# )705,393(lum
# final:  mul(393,507)
#
# why()
# )(yhw
#
# why()[-:,mul(715,497)
# )794,517(lum,:-[)(yhw
# )794,517(lum
# final:  mul(715,497)
#
# - @<;#)
# )#;<@ -
#
# - @<;#)?mul(450,459)
# )954,054(lum?)#;<@ -
# )954,054(lum
# final:  mul(450,459)
#
# select()
# )(tceles
#
# select()~$&mul(570,625)
# )526,075(lum&$~)(tceles
# )526,075(lum
# final:  mul(570,625)
#
# what()
# )(tahw
#
# what()mul(944,195)
# )591,449(lum)(tahw
# )591,449(lum
# final:  mul(944,195)
#
# select()
# )(tceles
#
# select()what()
# )(tahw)(tceles
#
# select()what()+%where()
# )(erehw%+)(tahw)(tceles
#
# select()what()+%where()where()
# )(erehw)(erehw%+)(tahw)(tceles
#
# select()what()+%where()where() /-,mul(203,571)
# )175,302(lum,-/ )(erehw)(erehw%+)(tahw)(tceles
# )175,302(lum
# final:  mul(203,571)
#
# (+why()
# )(yhw+(
#
# (+why()[(#^who()
# )(ohw^#([)(yhw+(
#
# (+why()[(#^who()~mul*where()
# )(erehw*lum~)(ohw^#([)(yhw+(
# )(erehw*lum
# final:  mul*where()
#
# (+why()[(#^who()~mul*where(),why()
# )(yhw,)(erehw*lum~)(ohw^#([)(yhw+(
# )(yhw,)(erehw*lum
# final:  mul*where(),why()
#
# (+why()[(#^who()~mul*where(),why()~~why()
# )(yhw~~)(yhw,)(erehw*lum~)(ohw^#([)(yhw+(
# )(yhw~~)(yhw,)(erehw*lum
# final:  mul*where(),why()~~why()
#
# (+why()[(#^who()~mul*where(),why()~~why()'@mul(469,314)
# )413,964(lum@')(yhw~~)(yhw,)(erehw*lum~)(ohw^#([)(yhw+(
# )413,964(lum
# final:  mul(469,314)
#
# mul(839,867)
# )768,938(lum
# )768,938(lum
# final:  mul(839,867)
#
# mul(607,678)
# )876,706(lum
# )876,706(lum
# final:  mul(607,678)
#
# 'do()
# )(od'
#
# 'do()*when()
# )(nehw*)(od'
#
# 'do()*when()<?{mul~~{/$^{#^how()
# )(woh^#{^$/{~~lum{?<)(nehw*)(od'
# )(woh^#{^$/{~~lum
# final:  mul~~{/$^{#^how()
#
# 'do()*when()<?{mul~~{/$^{#^how()$mul(733,382)
# )283,337(lum$)(woh^#{^$/{~~lum{?<)(nehw*)(od'
# )283,337(lum
# final:  mul(733,382)
#
# {/select()
# )(tceles/{
#
# {/select()~%mul(450,74)
# )47,054(lum%~)(tceles/{
# )47,054(lum
# final:  mul(450,74)
#
# what()
# )(tahw
#
# what()%'}where()
# )(erehw}'%)(tahw
#
# what()%'}where()from()
# )(morf)(erehw}'%)(tahw
# )(m
# final:  m()
#
# what()%'}where()from()select()
# )(tceles)(morf)(erehw}'%)(tahw
# )(tceles)(m
# final:  m()select()
#
# what()%'}where()from()select()%mul(139,672)
# )276,931(lum%)(tceles)(morf)(erehw}'%)(tahw
# )276,931(lum
# final:  mul(139,672)
#
# /,%*)
# )*%,/
#
# /,%*)*mul}{*how()
# )(woh*{}lum*)*%,/
# )(woh*{}lum
# final:  mul}{*how()
#
# /,%*)*mul}{*how()[mul(466,481)
# )184,664(lum[)(woh*{}lum*)*%,/
# )184,664(lum
# final:  mul(466,481)
#
# ]'@/}+%how()
# )(woh%+}/@']
#
# ]'@/}+%how()-mul(474,988)
# )889,474(lum-)(woh%+}/@']
# )889,474(lum
# final:  mul(474,988)
#
# ,mul(431,193)
# )391,134(lum,
# )391,134(lum
# final:  mul(431,193)
#
# ,mul(587,948)
# )849,785(lum,
# )849,785(lum
# final:  mul(587,948)
#
# when()
# )(nehw
#
# when()~/'mul(871,567)
# )765,178(lum'/~)(nehw
# )765,178(lum
# final:  mul(871,567)
#
# !?from()
# )(morf?!
# )(m
# final:  m()
#
# !?from()select(177,40)
# )04,771(tceles)(morf?!
# )04,771(tceles)(m
# final:  m()select(177,40)
#
# !?from()select(177,40)}how()
# )(woh})04,771(tceles)(morf?!
# )(woh})04,771(tceles)(m
# final:  m()select(177,40)}how()
#
# !?from()select(177,40)}how()when()
# )(nehw)(woh})04,771(tceles)(morf?!
# )(nehw)(woh})04,771(tceles)(m
# final:  m()select(177,40)}how()when()
#
# !?from()select(177,40)}how()when()mul(974,456)
# )654,479(lum)(nehw)(woh})04,771(tceles)(morf?!
# )654,479(lum
# final:  mul(974,456)
#
# ]<)
# )<]
#
# ]<)select()
# )(tceles)<]
#
# ]<)select()]><mul(292,269)
# )962,292(lum<>])(tceles)<]
# )962,292(lum
# final:  mul(292,269)
#
# why()
# )(yhw
#
# why()-)
# )-)(yhw
#
# why()-),mul(507,563)
# )365,705(lum,)-)(yhw
# )365,705(lum
# final:  mul(507,563)
#
# !how()
# )(woh!
#
# !how()&'from()
# )(morf'&)(woh!
# )(m
# final:  m()
#
# !how()&'from():mul(875$[+select()
# )(tceles+[$578(lum:)(morf'&)(woh!
# )(tceles+[$578(lum
# final:  mul(875$[+select()
# )(tceles+[$578(lum
# final:  mul(875$[+select()
#
# !how()&'from():mul(875$[+select();~+mul(243,139)
# )931,342(lum+~;)(tceles+[$578(lum:)(morf'&)(woh!
# )931,342(lum
# final:  mul(243,139)
#
# #when()
# )(nehw#
#
# #when()$when()
# )(nehw$)(nehw#
#
# #when()$when()[:mul(212,698)
# )896,212(lum:[)(nehw$)(nehw#
# )896,212(lum
# final:  mul(212,698)
#
# }where()
# )(erehw}
#
# }where()#^)
# )^#)(erehw}
#
# }where()#^)'when()
# )(nehw')^#)(erehw}
#
# }where()#^)'when()what()
# )(tahw)(nehw')^#)(erehw}
#
# }where()#^)'when()what();mul(40,183)
# )381,04(lum;)(tahw)(nehw')^#)(erehw}
# )381,04(lum
# final:  mul(40,183)
#
# what()
# )(tahw
#
# what();{]where()
# )(erehw]{;)(tahw
#
# what();{]where()how()
# )(woh)(erehw]{;)(tahw
#
# what();{]where()how()+where()
# )(erehw+)(woh)(erehw]{;)(tahw
#
# what();{]where()how()+where()mul(362,950)
# )059,263(lum)(erehw+)(woh)(erehw]{;)(tahw
# )059,263(lum
# final:  mul(362,950)
#
# #select()
# )(tceles#
#
# #select()mul(618,187)
# )781,816(lum)(tceles#
# )781,816(lum
# final:  mul(618,187)
#
# (mul(504,988)
# )889,405(lum(
# )889,405(lum
# final:  mul(504,988)
#
# ?'/ who()
# )(ohw /'?
#
# ?'/ who()+select()
# )(tceles+)(ohw /'?
#
# ?'/ who()+select()where()
# )(erehw)(tceles+)(ohw /'?
#
# ?'/ who()+select()where()mul(236,898)
# )898,632(lum)(erehw)(tceles+)(ohw /'?
# )898,632(lum
# final:  mul(236,898)
#
# <~>:>?mul(285,955)
# )559,582(lum?>:>~<
# )559,582(lum
# final:  mul(285,955)
#
# what()
# )(tahw
#
# what()/}when()
# )(nehw}/)(tahw
#
# what()/}when(){-why()
# )(yhw-{)(nehw}/)(tahw
#
# what()/}when(){-why()mul(358,393)
# )393,853(lum)(yhw-{)(nehw}/)(tahw
# )393,853(lum
# final:  mul(358,393)
#
# >@[where()
# )(erehw[@>
#
# >@[where()(who()
# )(ohw()(erehw[@>
#
# >@[where()(who()mul(676,462)
# )264,676(lum)(ohw()(erehw[@>
# )264,676(lum
# final:  mul(676,462)
#
# &]why()
# )(yhw]&
#
# &]why()&how()
# )(woh&)(yhw]&
#
# &]why()&how())
# ))(woh&)(yhw]&
#
# &]why()&how())mul(872,847@+#:mul(274,134)
# )431,472(lum:#+@748,278(lum))(woh&)(yhw]&
# )431,472(lum
# final:  mul(274,134)
#
# {/how(53,761)
# )167,35(woh/{
#
# {/how(53,761)>mul(895,912)
# )219,598(lum>)167,35(woh/{
# )219,598(lum
# final:  mul(895,912)
#
# why()
# )(yhw
#
# why()!*>^-]why()
# )(yhw]-^>*!)(yhw
#
# why()!*>^-]why()what()
# )(tahw)(yhw]-^>*!)(yhw
#
# why()!*>^-]why()what()don't()
# )(t'nod)(tahw)(yhw]-^>*!)(yhw
#
# why()!*>^-]why()what()don't()/)
# )/)(t'nod)(tahw)(yhw]-^>*!)(yhw
#
# why()!*>^-]why()what()don't()/)mul(219,961)
# )169,912(lum)/)(t'nod)(tahw)(yhw]-^>*!)(yhw
# )169,912(lum
# final:  mul(219,961)
#
# where()
# )(erehw
#
# where()how()
# )(woh)(erehw
#
# where()how()[^~'-<mul(481,864)
# )468,184(lum<-'~^[)(woh)(erehw
# )468,184(lum
# final:  mul(481,864)
#
# why()
# )(yhw
#
# why()who(598,406)
# )604,895(ohw)(yhw
#
# why()who(598,406))
# ))604,895(ohw)(yhw
#
# why()who(598,406))where()
# )(erehw))604,895(ohw)(yhw
#
# why()who(598,406))where()~][~mul(392,606)
# )606,293(lum~[]~)(erehw))604,895(ohw)(yhw
# )606,293(lum
# final:  mul(392,606)
#
# why(122,687)
# )786,221(yhw
#
# why(122,687)'(when()
# )(nehw(')786,221(yhw
#
# why(122,687)'(when()@^mul(920,948)
# )849,029(lum^@)(nehw(')786,221(yhw
# )849,029(lum
# final:  mul(920,948)
#
# @what()
# )(tahw@
#
# @what()where()
# )(erehw)(tahw@
#
# @what()where()select()
# )(tceles)(erehw)(tahw@
#
# @what()where()select()%,??select()
# )(tceles??,%)(tceles)(erehw)(tahw@
#
# @what()where()select()%,??select()]mul(629,795)
# )597,926(lum])(tceles??,%)(tceles)(erehw)(tahw@
# )597,926(lum
# final:  mul(629,795)
#
# mul(645,709)
# )907,546(lum
# )907,546(lum
# final:  mul(645,709)
#
# '-from()
# )(morf-'
# )(m
# final:  m()
#
# '-from()where()
# )(erehw)(morf-'
# )(erehw)(m
# final:  m()where()
#
# '-from()where()why()
# )(yhw)(erehw)(morf-'
# )(yhw)(erehw)(m
# final:  m()where()why()
#
# '-from()where()why()>^{when()
# )(nehw{^>)(yhw)(erehw)(morf-'
# )(nehw{^>)(yhw)(erehw)(m
# final:  m()where()why()>^{when()
#
# '-from()where()why()>^{when()mul(177>&,,'}from()
# )(morf}',,&>771(lum)(nehw{^>)(yhw)(erehw)(morf-'
# )(m
# final:  m()
# )(m
# final:  m()
# )(m
# final:  m()
#
# '-from()where()why()>^{when()mul(177>&,,'}from(),what()
# )(tahw,)(morf}',,&>771(lum)(nehw{^>)(yhw)(erehw)(morf-'
# )(tahw,)(m
# final:  m(),what()
# )(tahw,)(m
# final:  m(),what()
# )(tahw,)(m
# final:  m(),what()
#
# '-from()where()why()>^{when()mul(177>&,,'}from(),what()mul(314,86)
# )68,413(lum)(tahw,)(morf}',,&>771(lum)(nehw{^>)(yhw)(erehw)(morf-'
# )68,413(lum
# final:  mul(314,86)
#
#  ]{mul(74,407)
# )704,47(lum{]
# )704,47(lum
# final:  mul(74,407)
#
# <mul(593,327)
# )723,395(lum<
# )723,395(lum
# final:  mul(593,327)
#
# [select()
# )(tceles[
#
# [select()mul(411,974)
# )479,114(lum)(tceles[
# )479,114(lum
# final:  mul(411,974)
#
# >how()
# )(woh>
#
# >how()]!;(}don't()
# )(t'nod}(;!])(woh>
#
# >how()]!;(}don't()how()
# )(woh)(t'nod}(;!])(woh>
#
# >how()]!;(}don't()how())
# ))(woh)(t'nod}(;!])(woh>
#
# >how()]!;(}don't()how())mul(395,998)
# )899,593(lum))(woh)(t'nod}(;!])(woh>
# )899,593(lum
# final:  mul(395,998)
#
# ]select(415,991)
# )199,514(tceles]
#
# ]select(415,991){<mul(491)
# )194(lum<{)199,514(tceles]
# )194(lum
# final:  mul(491)
#
# ]select(415,991){<mul(491)<!'[~/;'what()
# )(tahw';/~['!<)194(lum<{)199,514(tceles]
# )(tahw';/~['!<)194(lum
# final:  mul(491)<!'[~/;'what()
#
# ]select(415,991){<mul(491)<!'[~/;'what()mul(989,530)
# )035,989(lum)(tahw';/~['!<)194(lum<{)199,514(tceles]
# )035,989(lum
# final:  mul(989,530)
#
# mul~$who()
# )(ohw$~lum
# )(ohw$~lum
# final:  mul~$who()
#
# mul~$who()/'+% mul(15,199)
# )991,51(lum %+'/)(ohw$~lum
# )991,51(lum
# final:  mul(15,199)
#
# )
# )
#
# )'where()
# )(erehw')
#
# )'where()when()
# )(nehw)(erehw')
#
# )'where()when()mul(816,920)
# )029,618(lum)(nehw)(erehw')
# )029,618(lum
# final:  mul(816,920)
#
# $why(317,997)
# )799,713(yhw$
#
# $why(317,997){ , /&mul(551,278)
# )872,155(lum&/ , {)799,713(yhw$
# )872,155(lum
# final:  mul(551,278)
#
# ?;,'$@who()
# )(ohw@$',;?
#
# ?;,'$@who()where()
# )(erehw)(ohw@$',;?
#
# ?;,'$@who()where()[}don't()
# )(t'nod}[)(erehw)(ohw@$',;?
#
# ?;,'$@who()where()[}don't()@select()
# )(tceles@)(t'nod}[)(erehw)(ohw@$',;?
#
# ?;,'$@who()where()[}don't()@select())
# ))(tceles@)(t'nod}[)(erehw)(ohw@$',;?
#
# ?;,'$@who()where()[}don't()@select()):who()
# )(ohw:))(tceles@)(t'nod}[)(erehw)(ohw@$',;?
#
# ?;,'$@who()where()[}don't()@select()):who()how()
# )(woh)(ohw:))(tceles@)(t'nod}[)(erehw)(ohw@$',;?
#
# ?;,'$@who()where()[}don't()@select()):who()how()mul(863,732)
# )237,368(lum)(woh)(ohw:))(tceles@)(t'nod}[)(erehw)(ohw@$',;?
# )237,368(lum
# final:  mul(863,732)
#
# ~];^]who()
# )(ohw]^;]~
#
# ~];^]who()%}from()
# )(morf}%)(ohw]^;]~
# )(m
# final:  m()
#
# ~];^]who()%}from()where()
# )(erehw)(morf}%)(ohw]^;]~
# )(erehw)(m
# final:  m()where()
#
# ~];^]who()%}from()where()mul(223,748)
# )847,322(lum)(erehw)(morf}%)(ohw]^;]~
# )847,322(lum
# final:  mul(223,748)
#
# from()
# )(morf
# )(m
# final:  m()
#
# from()when()
# )(nehw)(morf
# )(nehw)(m
# final:  m()when()
#
# from()when()where()
# )(erehw)(nehw)(morf
# )(erehw)(nehw)(m
# final:  m()when()where()
#
# from()when()where()'+/where()
# )(erehw/+')(erehw)(nehw)(morf
# )(erehw/+')(erehw)(nehw)(m
# final:  m()when()where()'+/where()
#
# from()when()where()'+/where()what()
# )(tahw)(erehw/+')(erehw)(nehw)(morf
# )(tahw)(erehw/+')(erehw)(nehw)(m
# final:  m()when()where()'+/where()what()
#
# from()when()where()'+/where()what()]~mul(474,54)
# )45,474(lum~])(tahw)(erehw/+')(erehw)(nehw)(morf
# )45,474(lum
# final:  mul(474,54)
#
# what()
# )(tahw
#
# what(){}(~[-mul(284,25)
# )52,482(lum-[~(}{)(tahw
# )52,482(lum
# final:  mul(284,25)
#
# [&>do()
# )(od>&[
#
# [&>do()'who()
# )(ohw')(od>&[
#
# [&>do()'who(),];},mul(374,334)
# )433,473(lum,};],)(ohw')(od>&[
# )433,473(lum
# final:  mul(374,334)
#
# ,!)
# )!,
#
# ,!)who()
# )(ohw)!,
#
# ,!)who()(;}^{}mul(343,209)
# )902,343(lum}{^};()(ohw)!,
# )902,343(lum
# final:  mul(343,209)
#
# /what()
# )(tahw/
#
# /what()[+ [{mul(952,521)
# )125,259(lum{[ +[)(tahw/
# )125,259(lum
# final:  mul(952,521)
#
#  [?[}:mul(264,303)
# )303,462(lum:}[?[
# )303,462(lum
# final:  mul(264,303)
#
# where()
# )(erehw
#
# where()*~where()
# )(erehw~*)(erehw
#
# where()*~where()*'mul(984,690)
# )096,489(lum'*)(erehw~*)(erehw
# )096,489(lum
# final:  mul(984,690)
#
# :@@]mul(979,762)
# )267,979(lum]@@:
# )267,979(lum
# final:  mul(979,762)
#
# from()
# )(morf
# )(m
# final:  m()
#
# from()!(/why(976,660)
# )066,679(yhw/(!)(morf
# )066,679(yhw/(!)(m
# final:  m()!(/why(976,660)
#
# from()!(/why(976,660)who()
# )(ohw)066,679(yhw/(!)(morf
# )(ohw)066,679(yhw/(!)(m
# final:  m()!(/why(976,660)who()
#
# from()!(/why(976,660)who() mul(387,945)
# )549,783(lum )(ohw)066,679(yhw/(!)(morf
# )549,783(lum
# final:  mul(387,945)
#
# mul(885,520)
# )025,588(lum
# )025,588(lum
# final:  mul(885,520)
#
# $when()
# )(nehw$
#
# $when()%who()
# )(ohw%)(nehw$
#
# $when()%who()&mul(950,716)
# )617,059(lum&)(ohw%)(nehw$
# )617,059(lum
# final:  mul(950,716)
#
# [)
# )[
#
# [)when(84,652)
# )256,48(nehw)[
#
# [)when(84,652)who()
# )(ohw)256,48(nehw)[
#
# [)when(84,652)who()/&~^-don't()
# )(t'nod-^~&/)(ohw)256,48(nehw)[
#
# [)when(84,652)who()/&~^-don't()?$from()
# )(morf$?)(t'nod-^~&/)(ohw)256,48(nehw)[
# )(m
# final:  m()
#
# [)when(84,652)who()/&~^-don't()?$from()mul(712,945)
# )549,217(lum)(morf$?)(t'nod-^~&/)(ohw)256,48(nehw)[
# )549,217(lum
# final:  mul(712,945)
#
# # why()
# )(yhw #
#
# # why()&<}<why()
# )(yhw<}<&)(yhw #
#
# # why()&<}<why()]>mul(83,500)
# )005,38(lum>])(yhw<}<&)(yhw #
# )005,38(lum
# final:  mul(83,500)
#
# ?]:/mul(567,822)
# )228,765(lum/:]?
# )228,765(lum
# final:  mul(567,822)
#
# how()
# )(woh
#
# how()<mul(877,379)
# )973,778(lum<)(woh
# )973,778(lum
# final:  mul(877,379)
#
# -when()
# )(nehw-
#
# -when()where()
# )(erehw)(nehw-
#
# -when()where()mul(396>?why(515,831)
# )138,515(yhw?>693(lum)(erehw)(nehw-
# )138,515(yhw?>693(lum
# final:  mul(396>?why(515,831)
#
# -when()where()mul(396>?why(515,831)&[<[^mul(503,349)
# )943,305(lum^[<[&)138,515(yhw?>693(lum)(erehw)(nehw-
# )943,305(lum
# final:  mul(503,349)
#
#
# !*<,)
# ),<*!
#
#
#
# !*<,){$?'select()
# )(tceles'?${),<*!
#
#
#
# !*<,){$?'select()don't()
# )(t'nod)(tceles'?${),<*!
#
#
#
# !*<,){$?'select()don't()what()
# )(tahw)(t'nod)(tceles'?${),<*!
#
#
#
# !*<,){$?'select()don't()what()%,(!~mul(961,381)
# )183,169(lum~!(,%)(tahw)(t'nod)(tceles'?${),<*!
#
# )183,169(lum
# final:  mul(961,381)
#
# select()
# )(tceles
#
# select()*%why()
# )(yhw%*)(tceles
#
# select()*%why() when()
# )(nehw )(yhw%*)(tceles
#
# select()*%why() when()#$)
# )$#)(nehw )(yhw%*)(tceles
#
# select()*%why() when()#$)mul(380,949)
# )949,083(lum)$#)(nehw )(yhw%*)(tceles
# )949,083(lum
# final:  mul(380,949)
#
# ~$what(428,872)
# )278,824(tahw$~
#
# ~$what(428,872)how()
# )(woh)278,824(tahw$~
#
# ~$what(428,872)how()?&'+mul(261,613)
# )316,162(lum+'&?)(woh)278,824(tahw$~
# )316,162(lum
# final:  mul(261,613)
#
# what()
# )(tahw
#
# what()what()
# )(tahw)(tahw
#
# what()what()!'<what()
# )(tahw<'!)(tahw)(tahw
#
# what()what()!'<what()how()
# )(woh)(tahw<'!)(tahw)(tahw
#
# what()what()!'<what()how(),&mul(967,970)
# )079,769(lum&,)(woh)(tahw<'!)(tahw)(tahw
# )079,769(lum
# final:  mul(967,970)
#
# ,$-/*<~mul(587,914)
# )419,785(lum~<*/-$,
# )419,785(lum
# final:  mul(587,914)
#
# ]mul(753,127)
# )721,357(lum]
# )721,357(lum
# final:  mul(753,127)
#
# }~^/;()
# )(;/^~}
#
# }~^/;()>]'mul(292,235)
# )532,292(lum']>)(;/^~}
# )532,292(lum
# final:  mul(292,235)
#
#  select()
# )(tceles
#
#  select()from()
# )(morf)(tceles
# )(m
# final:  m()
#
#  select()from()@who()
# )(ohw@)(morf)(tceles
# )(ohw@)(m
# final:  m()@who()
#
#  select()from()@who()?^what()
# )(tahw^?)(ohw@)(morf)(tceles
# )(tahw^?)(ohw@)(m
# final:  m()@who()?^what()
#
#  select()from()@who()?^what()mul(383,544)
# )445,383(lum)(tahw^?)(ohw@)(morf)(tceles
# )445,383(lum
# final:  mul(383,544)
#
# :[mul(272,707)
# )707,272(lum[:
# )707,272(lum
# final:  mul(272,707)
#
# >(what()
# )(tahw(>
#
# >(what()mul(735,912)
# )219,537(lum)(tahw(>
# )219,537(lum
# final:  mul(735,912)
#
# }>when()
# )(nehw>}
#
# }>when()select()
# )(tceles)(nehw>}
#
# }>when()select()select()
# )(tceles)(tceles)(nehw>}
#
# }>when()select()select() {mul(62,107)
# )701,26(lum{ )(tceles)(tceles)(nehw>}
# )701,26(lum
# final:  mul(62,107)
#
# /]select()
# )(tceles]/
#
# /]select()mul(713,534)
# )435,317(lum)(tceles]/
# )435,317(lum
# final:  mul(713,534)
#
# )
# )
#
# ); #+/@?&/mul(572,504)
# )405,275(lum/&?@/+# ;)
# )405,275(lum
# final:  mul(572,504)
#
# )
# )
#
# )&)
# )&)
#
# )&)>who(951,467)
# )764,159(ohw>)&)
#
# )&)>who(951,467),{*^&mul(31,687)
# )786,13(lum&^*{,)764,159(ohw>)&)
# )786,13(lum
# final:  mul(31,687)
#
# {mul(313,607)
# )706,313(lum{
# )706,313(lum
# final:  mul(313,607)
#
# ><,what(496,388)
# )883,694(tahw,<>
#
# ><,what(496,388) ]why(521,85)
# )58,125(yhw] )883,694(tahw,<>
#
# ><,what(496,388) ]why(521,85)(mul(690,876)
# )678,096(lum()58,125(yhw] )883,694(tahw,<>
# )678,096(lum
# final:  mul(690,876)
#
# )
# )
#
# )::'@<where()
# )(erehw<@'::)
#
# )::'@<where()mul(273,373)
# )373,372(lum)(erehw<@'::)
# )373,372(lum
# final:  mul(273,373)
#
# %/mul(843why()
# )(yhw348(lum/%
# )(yhw348(lum
# final:  mul(843why()
#
# %/mul(843why()%*)
# )*%)(yhw348(lum/%
# )*%)(yhw348(lum
# final:  mul(843why()%*)
#
# %/mul(843why()%*)&/@[,?why()
# )(yhw?,[@/&)*%)(yhw348(lum/%
# )(yhw?,[@/&)*%)(yhw348(lum
# final:  mul(843why()%*)&/@[,?why()
#
# %/mul(843why()%*)&/@[,?why()mul(531,235)
# )532,135(lum)(yhw?,[@/&)*%)(yhw348(lum/%
# )532,135(lum
# final:  mul(531,235)
#
# mul(111,213)
# )312,111(lum
# )312,111(lum
# final:  mul(111,213)
#
# where()
# )(erehw
#
# where()~who()
# )(ohw~)(erehw
#
# where()~who()/+mul(189,15)
# )51,981(lum+/)(ohw~)(erehw
# )51,981(lum
# final:  mul(189,15)
#
# -%~why()
# )(yhw~%-
#
# -%~why()@'mul(964,850)
# )058,469(lum'@)(yhw~%-
# )058,469(lum
# final:  mul(964,850)
#
# [why()
# )(yhw[
#
# [why()who()
# )(ohw)(yhw[
#
# [why()who()who()
# )(ohw)(ohw)(yhw[
#
# [why()who()who():$&-where()
# )(erehw-&$:)(ohw)(ohw)(yhw[
#
# [why()who()who():$&-where()do()
# )(od)(erehw-&$:)(ohw)(ohw)(yhw[
#
# [why()who()who():$&-where()do()why()
# )(yhw)(od)(erehw-&$:)(ohw)(ohw)(yhw[
#
# [why()who()who():$&-where()do()why(){when()
# )(nehw{)(yhw)(od)(erehw-&$:)(ohw)(ohw)(yhw[
#
# [why()who()who():$&-where()do()why(){when()mul(434,480)
# )084,434(lum)(nehw{)(yhw)(od)(erehw-&$:)(ohw)(ohw)(yhw[
# )084,434(lum
# final:  mul(434,480)
#
# ;from()
# )(morf;
# )(m
# final:  m()
#
# ;from())
# ))(morf;
# ))(m
# final:  m())
#
# ;from())mul(579,808)
# )808,975(lum))(morf;
# )808,975(lum
# final:  mul(579,808)
#
# +[ ~ $ when()
# )(nehw $ ~ [+
#
# +[ ~ $ when()mul(856,871)
# )178,658(lum)(nehw $ ~ [+
# )178,658(lum
# final:  mul(856,871)
#
# :[^,when()
# )(nehw,^[:
#
# :[^,when()what()
# )(tahw)(nehw,^[:
#
# :[^,when()what()how()
# )(woh)(tahw)(nehw,^[:
#
# :[^,when()what()how()mul(191[;(mul(900,159)
# )951,009(lum(;[191(lum)(woh)(tahw)(nehw,^[:
# )951,009(lum
# final:  mul(900,159)
#
# how()
# )(woh
#
# how()-,from()
# )(morf,-)(woh
# )(m
# final:  m()
#
# how()-,from()()
# )()(morf,-)(woh
# )()(m
# final:  m()()
#
# how()-,from()()do()
# )(od)()(morf,-)(woh
# )(od)()(m
# final:  m()()do()
#
# how()-,from()()do();who()
# )(ohw;)(od)()(morf,-)(woh
# )(ohw;)(od)()(m
# final:  m()()do();who()
#
# how()-,from()()do();who()')
# )')(ohw;)(od)()(morf,-)(woh
# )')(ohw;)(od)()(m
# final:  m()()do();who()')
#
# how()-,from()()do();who()');-!>why()
# )(yhw>!-;)')(ohw;)(od)()(morf,-)(woh
# )(yhw>!-;)')(ohw;)(od)()(m
# final:  m()()do();who()');-!>why()
#
# how()-,from()()do();who()');-!>why()who()
# )(ohw)(yhw>!-;)')(ohw;)(od)()(morf,-)(woh
# )(ohw)(yhw>!-;)')(ohw;)(od)()(m
# final:  m()()do();who()');-!>why()who()
#
# how()-,from()()do();who()');-!>why()who()mul(596,341)
# )143,695(lum)(ohw)(yhw>!-;)')(ohw;)(od)()(morf,-)(woh
# )143,695(lum
# final:  mul(596,341)
#
# <,mul(455,990)
# )099,554(lum,<
# )099,554(lum
# final:  mul(455,990)
#
# <{mul(497,180)
# )081,794(lum{<
# )081,794(lum
# final:  mul(497,180)
#
# when()
# )(nehw
#
# when()select()
# )(tceles)(nehw
#
# when()select()@ -mul(613,543)
# )345,316(lum- @)(tceles)(nehw
# )345,316(lum
# final:  mul(613,543)
#
# don't()
# )(t'nod
#
# don't(){what()
# )(tahw{)(t'nod
#
# don't(){what()~[where()
# )(erehw[~)(tahw{)(t'nod
#
# don't(){what()~[where()] ,^mul(333,124)
# )421,333(lum^, ])(erehw[~)(tahw{)(t'nod
# )421,333(lum
# final:  mul(333,124)
#
# {where()
# )(erehw{
#
# {where()where()
# )(erehw)(erehw{
#
# {where()where()>!:mul(545,512)
# )215,545(lum:!>)(erehw)(erehw{
# )215,545(lum
# final:  mul(545,512)
#
# why()
# )(yhw
#
# why()(mul(561,668)
# )866,165(lum()(yhw
# )866,165(lum
# final:  mul(561,668)
#
# what()
# )(tahw
#
# what()%^/(mul(478,75)
# )57,874(lum(/^%)(tahw
# )57,874(lum
# final:  mul(478,75)
#
# @where()
# )(erehw@
#
# @where()mul(329,992)
# )299,923(lum)(erehw@
# )299,923(lum
# final:  mul(329,992)
#
# $from()
# )(morf$
# )(m
# final:  m()
#
# $from(): ,*mul(866(}*)
# )*}(668(lum*, :)(morf$
# )*}(668(lum
# final:  mul(866(}*)
# )*}(668(lum
# final:  mul(866(}*)
#
# $from(): ,*mul(866(}*)why()
# ...
# +mul(682,133)
# )331,286(lum+
# )331,286(lum
# final:  mul(682,133)
#
# {+'[mul(846,821)
# )128,648(lum['+{
# )128,648(lum
# final:  mul(846,821)
#
# ]%}@)
# )@}%]
#
# ]%}@)&mul(116,347)
# )743,611(lum&)@}%]
# )743,611(lum
# final:  mul(116,347)
#
# who()
# )(ohw
#
# who()/'<~mul(924,51)
# )15,429(lum~<'/)(ohw
# )15,429(lum
# final:  mul(924,51)
#
# $,when()
# )(nehw,$
#
# $,when()>(from()
# )(morf(>)(nehw,$
# )(m
# final:  m()
#
# $,when()>(from()!mul(209,245)
# )542,902(lum!)(morf(>)(nehw,$
# )542,902(lum
# final:  mul(209,245)
#
# (@'where()
# )(erehw'@(
#
# (@'where()select()
# )(tceles)(erehw'@(
#
# (@'where()select()?]/mul(460,178)
# )871,064(lum/]?)(tceles)(erehw'@(
# )871,064(lum
# final:  mul(460,178)
#
# -/why(825,431)
# )134,528(yhw/-
#
# -/why(825,431)!do()
# )(od!)134,528(yhw/-
#
# -/why(825,431)!do()what()
# )(tahw)(od!)134,528(yhw/-
#
# -/why(825,431)!do()what()<how()
# )(woh<)(tahw)(od!)134,528(yhw/-
#
# -/why(825,431)!do()what()<how()mul(517,419)
# )914,715(lum)(woh<)(tahw)(od!)134,528(yhw/-
# )914,715(lum
# final:  mul(517,419)
#
# :{~,-;!&mul(631,707who()
# )(ohw707,136(lum&!;-,~{:
# )(ohw707,136(lum
# final:  mul(631,707who()
#
# :{~,-;!&mul(631,707who()/&)
# )&/)(ohw707,136(lum&!;-,~{:
# )&/)(ohw707,136(lum
# final:  mul(631,707who()/&)
#
# :{~,-;!&mul(631,707who()/&)]+;where()
# )(erehw;+])&/)(ohw707,136(lum&!;-,~{:
# )(erehw;+])&/)(ohw707,136(lum
# final:  mul(631,707who()/&)]+;where()
#
# :{~,-;!&mul(631,707who()/&)]+;where():)
# ):)(erehw;+])&/)(ohw707,136(lum&!;-,~{:
# ):)(erehw;+])&/)(ohw707,136(lum
# final:  mul(631,707who()/&)]+;where():)
#
# :{~,-;!&mul(631,707who()/&)]+;where():)mul(68,998)
# )899,86(lum):)(erehw;+])&/)(ohw707,136(lum&!;-,~{:
# )899,86(lum
# final:  mul(68,998)
#
# when()
# )(nehw
#
# when(){~how()
# )(woh~{)(nehw
#
# when(){~how()where()
# )(erehw)(woh~{)(nehw
#
# when(){~how()where()from(622,385)
# )583,226(morf)(erehw)(woh~{)(nehw
# )583,226(m
# final:  m(622,385)
#
# when(){~how()where()from(622,385)!)
# )!)583,226(morf)(erehw)(woh~{)(nehw
# )!)583,226(m
# final:  m(622,385)!)
#
# when(){~how()where()from(622,385)!)!mul(587,990)
# )099,785(lum!)!)583,226(morf)(erehw)(woh~{)(nehw
# )099,785(lum
# final:  mul(587,990)
#
# -[ ^>{!mul(765,879)
# )978,567(lum!{>^ [-
# )978,567(lum
# final:  mul(765,879)
#
# &&mul(798,713)
# )317,897(lum&&
# )317,897(lum
# final:  mul(798,713)
#
# where()
# )(erehw
#
# where()who()
# )(ohw)(erehw
#
# where()who()from()
# )(morf)(ohw)(erehw
# )(m
# final:  m()
#
# where()who()from()~mul(739,10)
# )01,937(lum~)(morf)(ohw)(erehw
# )01,937(lum
# final:  mul(739,10)
#
# %] :>-when()
# )(nehw->: ]%
#
# %] :>-when()]mul(131,912)
# )219,131(lum])(nehw->: ]%
# )219,131(lum
# final:  mul(131,912)
#
# ?{ {$>?why()
# )(yhw?>${ {?
#
# ?{ {$>?why()$+mul(825,581)
# )185,528(lum+$)(yhw?>${ {?
# )185,528(lum
# final:  mul(825,581)
#
# what()
# )(tahw
#
# what()mul(905,252)
# )252,509(lum)(tahw
# )252,509(lum
# final:  mul(905,252)
#
# &when()
# )(nehw&
#
# &when()>,%}'%-what()
# )(tahw-%'}%,>)(nehw&
#
# &when()>,%}'%-what()don't()
# )(t'nod)(tahw-%'}%,>)(nehw&
#
# &when()>,%}'%-what()don't()~$where()
# )(erehw$~)(t'nod)(tahw-%'}%,>)(nehw&
#
# &when()>,%}'%-what()don't()~$where())
# ))(erehw$~)(t'nod)(tahw-%'}%,>)(nehw&
#
# &when()>,%}'%-what()don't()~$where())?when()
# )(nehw?))(erehw$~)(t'nod)(tahw-%'}%,>)(nehw&
#
# &when()>,%}'%-what()don't()~$where())?when()?from(968,779)
# )977,869(morf?)(nehw?))(erehw$~)(t'nod)(tahw-%'}%,>)(nehw&
# )977,869(m
# final:  m(968,779)
#
# &when()>,%}'%-what()don't()~$where())?when()?from(968,779)mul(863,782)
# )287,368(lum)977,869(morf?)(nehw?))(erehw$~)(t'nod)(tahw-%'}%,>)(nehw&
# )287,368(lum
# final:  mul(863,782)
#
# ^$<mul(631,509)
# )905,136(lum<$^
# )905,136(lum
# final:  mul(631,509)
#
# $mul(930,251)
# )152,039(lum$
# )152,039(lum
# final:  mul(930,251)
#
# ?~!+'what()
# )(tahw'+!~?
#
# ?~!+'what()+(<select()
# )(tceles<(+)(tahw'+!~?
#
# ?~!+'what()+(<select()mul(204,65)
# )56,402(lum)(tceles<(+)(tahw'+!~?
# )56,402(lum
# final:  mul(204,65)
#
# mul(231,133)
# )331,132(lum
# )331,132(lum
# final:  mul(231,133)
#
# $why()
# )(yhw$
#
# $why()^%mul(332,786)
# )687,233(lum%^)(yhw$
# )687,233(lum
# final:  mul(332,786)
#
# why()
# )(yhw
#
# why()!~;who()
# )(ohw;~!)(yhw
#
# why()!~;who()[from()
# )(morf[)(ohw;~!)(yhw
# )(m
# final:  m()
#
# why()!~;who()[from()mul(726,913)
# )319,627(lum)(morf[)(ohw;~!)(yhw
# )319,627(lum
# final:  mul(726,913)
#
# /from()
# )(morf/
# )(m
# final:  m()
#
# /from()mul(484,642)
# )246,484(lum)(morf/
# )246,484(lum
# final:  mul(484,642)
#
# :(!when()
# )(nehw!(:
#
# :(!when()/what()
# )(tahw/)(nehw!(:
#
# :(!when()/what():#(?mul(590,989)
# )989,095(lum?(#:)(tahw/)(nehw!(:
# )989,095(lum
# final:  mul(590,989)
#
# ,{what()
# )(tahw{,
#
# ,{what()&who()
# )(ohw&)(tahw{,
#
# ,{what()&who()~mul(879,143)
# )341,978(lum~)(ohw&)(tahw{,
# )341,978(lum
# final:  mul(879,143)
#
# !{{-;why()
# )(yhw;-{{!
#
# !{{-;why() ]:where()
# )(erehw:] )(yhw;-{{!
#
# !{{-;why() ]:where()don't()
# )(t'nod)(erehw:] )(yhw;-{{!
#
# !{{-;why() ]:where()don't()-~>;:[!~what()
# )(tahw~![:;>~-)(t'nod)(erehw:] )(yhw;-{{!
#
# !{{-;why() ]:where()don't()-~>;:[!~what()mul(498,143)
# )341,894(lum)(tahw~![:;>~-)(t'nod)(erehw:] )(yhw;-{{!
# )341,894(lum
# final:  mul(498,143)
#
# what()
# )(tahw
#
# what()!*why()
# )(yhw*!)(tahw
#
# what()!*why()mul(347,195)
# )591,743(lum)(yhw*!)(tahw
# )591,743(lum
# final:  mul(347,195)
#
# #/mul(930,586)
# )685,039(lum/#
# )685,039(lum
# final:  mul(930,586)
#
# -/select()
# )(tceles/-
#
# -/select()*:{mul(439,475>^from()
# )(morf^>574,934(lum{:*)(tceles/-
# )(m
# final:  m()
# )(m
# final:  m()
#
# -/select()*:{mul(439,475>^from() )
# ) )(morf^>574,934(lum{:*)(tceles/-
# ) )(m
# final:  m() )
# ) )(m
# final:  m() )
#
# -/select()*:{mul(439,475>^from() )^>>^)
# )^>>^) )(morf^>574,934(lum{:*)(tceles/-
# )^>>^) )(m
# final:  m() )^>>^)
# )^>>^) )(m
# final:  m() )^>>^)
#
# -/select()*:{mul(439,475>^from() )^>>^)why()
# )(yhw)^>>^) )(morf^>574,934(lum{:*)(tceles/-
# )(yhw)^>>^) )(m
# final:  m() )^>>^)why()
# )(yhw)^>>^) )(m
# final:  m() )^>>^)why()
#
# -/select()*:{mul(439,475>^from() )^>>^)why()mul(453,205)
# )502,354(lum)(yhw)^>>^) )(morf^>574,934(lum{:*)(tceles/-
# )502,354(lum
# final:  mul(453,205)
#
# when()
# )(nehw
#
# when()?[mul(75,857)
# )758,57(lum[?)(nehw
# )758,57(lum
# final:  mul(75,857)
#
# [when()
# )(nehw[
#
# [when()~how()
# )(woh~)(nehw[
#
# [when()~how())
# ))(woh~)(nehw[
#
# [when()~how())who()
# )(ohw))(woh~)(nehw[
#
# [when()~how())who(){when()
# )(nehw{)(ohw))(woh~)(nehw[
#
# [when()~how())who(){when()^+mul(201,137)
# )731,102(lum+^)(nehw{)(ohw))(woh~)(nehw[
# )731,102(lum
# final:  mul(201,137)
#
# >why()
# )(yhw>
#
# >why():!+who(645,81)
# )18,546(ohw+!:)(yhw>
#
# >why():!+who(645,81)[why()
# )(yhw[)18,546(ohw+!:)(yhw>
#
# >why():!+who(645,81)[why()mul(861,373)
# )373,168(lum)(yhw[)18,546(ohw+!:)(yhw>
# )373,168(lum
# final:  mul(861,373)
#
# :!when()
# )(nehw!:
#
# :!when()*how()
# )(woh*)(nehw!:
#
# :!when()*how()?'?;mul(410,947)
# )749,014(lum;?'?)(woh*)(nehw!:
# )749,014(lum
# final:  mul(410,947)
#
# what()
# )(tahw
#
# what()%^[>mul(106,316)
# )613,601(lum>[^%)(tahw
# )613,601(lum
# final:  mul(106,316)
#
# > ^(where()
# )(erehw(^ >
#
# > ^(where()~select()
# )(tceles~)(erehw(^ >
#
# > ^(where()~select()where()
# )(erehw)(tceles~)(erehw(^ >
#
# > ^(where()~select()where()what()
# )(tahw)(erehw)(tceles~)(erehw(^ >
#
# > ^(where()~select()where()what()mul(296,671)
# )176,692(lum)(tahw)(erehw)(tceles~)(erehw(^ >
# )176,692(lum
# final:  mul(296,671)
#
# %select()
# )(tceles%
#
# %select()&+{]*-when()
# )(nehw-*]{+&)(tceles%
#
# %select()&+{]*-when()mul(481,274)
# )472,184(lum)(nehw-*]{+&)(tceles%
# )472,184(lum
# final:  mul(481,274)
#
#  '$mul(929,179)
# )971,929(lum$'
# )971,929(lum
# final:  mul(929,179)
#
# &'&+ +~/%mul(29,898)
# )898,92(lum%/~+ +&'&
# )898,92(lum
# final:  mul(29,898)
#
# {^+{^/mul(580,352)
# )253,085(lum/^{+^{
# )253,085(lum
# final:  mul(580,352)
#
# when()
# )(nehw
#
# when()from()
# )(morf)(nehw
# )(m
# final:  m()
#
# when()from()]mul(585,530)
# )035,585(lum])(morf)(nehw
# )035,585(lum
# final:  mul(585,530)
#
# *'mul(638,910)
# )019,836(lum'*
# )019,836(lum
# final:  mul(638,910)
#
# &/:^don't()
# )(t'nod^:/&
#
# &/:^don't()->&!mul(894,636)
# )636,498(lum!&>-)(t'nod^:/&
# )636,498(lum
# final:  mul(894,636)
#
# when()
# )(nehw
#
# when()*when()
# )(nehw*)(nehw
#
# when()*when()mul(577,671)
# )176,775(lum)(nehw*)(nehw
# )176,775(lum
# final:  mul(577,671)
#
# }/~ <],$mul(999,788)
# )887,999(lum$,]< ~/}
# )887,999(lum
# final:  mul(999,788)
#
# /how()
# )(woh/
#
# /how()!;mul(574,638)
# )836,475(lum;!)(woh/
# )836,475(lum
# final:  mul(574,638)
#
# -where()
# )(erehw-
#
# -where()!^mul(66,674)
# )476,66(lum^!)(erehw-
# )476,66(lum
# final:  mul(66,674)
#
# /}mul(937,514)
# )415,739(lum}/
# )415,739(lum
# final:  mul(937,514)
#
# do()
# )(od
#
# do()([*,+@(who()
# )(ohw(@+,*[()(od
#
# do()([*,+@(who()*;mul(750,907)
# )709,057(lum;*)(ohw(@+,*[()(od
# )709,057(lum
# final:  mul(750,907)
#
# ^why()
# )(yhw^
#
# ^why()what()
# )(tahw)(yhw^
#
# ^why()what()[*>mul(303,172)
# )271,303(lum>*[)(tahw)(yhw^
# )271,303(lum
# final:  mul(303,172)
#
# *why()
# )(yhw*
#
# *why();how()
# )(woh;)(yhw*
#
# *why();how()+@}:;]mul(15,812)
# )218,51(lum];:}@+)(woh;)(yhw*
# )218,51(lum
# final:  mul(15,812)
#
# where()
# )(erehw
#
# where()-:where()
# )(erehw:-)(erehw
#
# where()-:where()~mul(673,466)
# )664,376(lum~)(erehw:-)(erehw
# )664,376(lum
# final:  mul(673,466)
#
# +{$'%mul(623,971)
# )179,326(lum%'${+
# )179,326(lum
# final:  mul(623,971)
#
# [select()
# )(tceles[
#
# [select()don't()
# )(t'nod)(tceles[
#
# [select()don't()mul(7,739)
# )937,7(lum)(t'nod)(tceles[
# )937,7(lum
# final:  mul(7,739)
#
# !&,)
# ),&!
#
# !&,)'who()
# )(ohw'),&!
#
# !&,)'who()%'mul(509,601)
# )106,905(lum'%)(ohw'),&!
# )106,905(lum
# final:  mul(509,601)
#
# )
# )
#
# )select()
# )(tceles)
#
# )select() do()
# )(od )(tceles)
#
# )select() do()select()
# )(tceles)(od )(tceles)
#
# )select() do()select()mul(36,79)
# )97,63(lum)(tceles)(od )(tceles)
# )97,63(lum
# final:  mul(36,79)
#
# mul(199,611)
# )116,991(lum
# )116,991(lum
# final:  mul(199,611)
#
# mul(983,700)
# )007,389(lum
# )007,389(lum
# final:  mul(983,700)
#
# @;?@how()
# )(woh@?;@
#
# @;?@how()why()
# )(yhw)(woh@?;@
#
# @;?@how()why()mul(136,594)
# )495,631(lum)(yhw)(woh@?;@
# )495,631(lum
# final:  mul(136,594)
#
# [+%}how()
# )(woh}%+[
#
# [+%}how()mul(34,407)
# )704,43(lum)(woh}%+[
# )704,43(lum
# final:  mul(34,407)
#
# [where()
# )(erehw[
#
# [where()^!when()
# )(nehw!^)(erehw[
#
# [where()^!when()don't()
# )(t'nod)(nehw!^)(erehw[
#
# [where()^!when()don't()~how()
# )(woh~)(t'nod)(nehw!^)(erehw[
#
# [where()^!when()don't()~how()(@mul(71,117)
# )711,17(lum@()(woh~)(t'nod)(nehw!^)(erehw[
# )711,17(lum
# final:  mul(71,117)
#
# {#?mul(857,810)
# )018,758(lum?#{
# )018,758(lum
# final:  mul(857,810)
#
# ,>[when()
# )(nehw[>,
#
# ,>[when()mul(993,232)
# )232,399(lum)(nehw[>,
# )232,399(lum
# final:  mul(993,232)
#
# what()
# )(tahw
#
# what()why()
# )(yhw)(tahw
#
# what()why() when()
# )(nehw )(yhw)(tahw
#
# what()why() when()~+${mul(103,182)
# )281,301(lum{$+~)(nehw )(yhw)(tahw
# )281,301(lum
# final:  mul(103,182)
#
# >-from()
# )(morf->
# )(m
# final:  m()
#
# >-from()<select(762,467)
# )764,267(tceles<)(morf->
# )764,267(tceles<)(m
# final:  m()<select(762,467)
#
# >-from()<select(762,467)how()
# )(woh)764,267(tceles<)(morf->
# )(woh)764,267(tceles<)(m
# final:  m()<select(762,467)how()
#
# >-from()<select(762,467)how() *<mul(607,926)
# )629,706(lum<* )(woh)764,267(tceles<)(morf->
# )629,706(lum
# final:  mul(607,926)
#
# mul(606,36)
# )63,606(lum
# )63,606(lum
# final:  mul(606,36)
#
# $>from()
# )(morf>$
# )(m
# final:  m()
#
# $>from(),mul(756,418)
# )814,657(lum,)(morf>$
# )814,657(lum
# final:  mul(756,418)
#
# )
# )
#
# ):what()
# )(tahw:)
#
# ):what()'~from()
# )(morf~')(tahw:)
# )(m
# final:  m()
#
# ):what()'~from()select()
# )(tceles)(morf~')(tahw:)
# )(tceles)(m
# final:  m()select()
#
# ):what()'~from()select()mul(833,12)
# )21,338(lum)(tceles)(morf~')(tahw:)
# )21,338(lum
# final:  mul(833,12)
#
# <#why()
# )(yhw#<
#
# <#why()~$ ,mul(74,614)
# )416,47(lum, $~)(yhw#<
# )416,47(lum
# final:  mul(74,614)
#
# :from()
# )(morf:
# )(m
# final:  m()
#
# :from()% @{]from()
# )(morf]{@ %)(morf:
# )(m
# final:  m()
# )(m
# final:  m()
#
# :from()% @{]from()+:mul(120,343)
# )343,021(lum:+)(morf]{@ %)(morf:
# )343,021(lum
# final:  mul(120,343)
#
# mul(714,187)
# )781,417(lum
# )781,417(lum
# final:  mul(714,187)
#
# why()
# )(yhw
#
# why():mul(379,724)
# )427,973(lum:)(yhw
# )427,973(lum
# final:  mul(379,724)
#
# ^select()
# )(tceles^
#
# ^select()-$-?$who()
# )(ohw$?-$-)(tceles^
#
# ^select()-$-?$who()~who()
# )(ohw~)(ohw$?-$-)(tceles^
#
# ^select()-$-?$who()~who()mul(5,213)
# )312,5(lum)(ohw~)(ohw$?-$-)(tceles^
# )312,5(lum
# final:  mul(5,213)
#
# )
# )
#
# )(,?]mul(151,375)
# )573,151(lum]?,()
# )573,151(lum
# final:  mul(151,375)
#
# )
# )
#
# )^$:;@:mul(34,537)
# )735,43(lum:@;:$^)
# )735,43(lum
# final:  mul(34,537)
#
# ${&!-#,[mul(289,643)
# )346,982(lum[,#-!&{$
# )346,982(lum
# final:  mul(289,643)
#
# what()
# )(tahw
#
# what()why()
# )(yhw)(tahw
#
# what()why()>select()
# )(tceles>)(yhw)(tahw
#
# what()why()>select()select()
# )(tceles)(tceles>)(yhw)(tahw
#
# what()why()>select()select()mul(938,238)
# )832,839(lum)(tceles)(tceles>)(yhw)(tahw
# )832,839(lum
# final:  mul(938,238)
#
# +mul(32,613)
# )316,23(lum+
# )316,23(lum
# final:  mul(32,613)
#
# mul(415,379)
# )973,514(lum
# )973,514(lum
# final:  mul(415,379)
#
# [,<~$$don't()
# )(t'nod$$~<,[
#
# [,<~$$don't()mul(272,584)
# )485,272(lum)(t'nod$$~<,[
# )485,272(lum
# final:  mul(272,584)
#
# ?-]&mul(164,981)
# )189,461(lum&]-?
# )189,461(lum
# final:  mul(164,981)
#
# ,>+how(623,296)
# )692,326(woh+>,
#
# ,>+how(623,296)<select()
# )(tceles<)692,326(woh+>,
#
# ,>+how(623,296)<select()who()
# )(ohw)(tceles<)692,326(woh+>,
#
# ,>+how(623,296)<select()who()%(where(396,349)
# )943,693(erehw(%)(ohw)(tceles<)692,326(woh+>,
#
# ,>+how(623,296)<select()who()%(where(396,349)mul(37,177)
# )771,73(lum)943,693(erehw(%)(ohw)(tceles<)692,326(woh+>,
# )771,73(lum
# final:  mul(37,177)
#
# [)
# )[
#
# [)mul(527,858)
# )858,725(lum)[
# )858,725(lum
# final:  mul(527,858)
#
# ~*<?select()
# )(tceles?<*~
#
# ~*<?select()&&#+:mul(411,460)
# )064,114(lum:+#&&)(tceles?<*~
# )064,114(lum
# final:  mul(411,460)
#
# *%<@>!{+mul(628,434)
# )434,826(lum+{!>@<%*
# )434,826(lum
# final:  mul(628,434)
#
# why()
# )(yhw
#
# why()how()
# )(woh)(yhw
#
# why()how()(who()
# )(ohw()(woh)(yhw
#
# why()how()(who()~-($how()
# )(woh$(-~)(ohw()(woh)(yhw
#
# why()how()(who()~-($how()mul(912,947)
# )749,219(lum)(woh$(-~)(ohw()(woh)(yhw
# )749,219(lum
# final:  mul(912,947)
#
# }mul(279,831)
# )138,972(lum}
# )138,972(lum
# final:  mul(279,831)
#
# where()
# )(erehw
#
# where()(++select()
# )(tceles++()(erehw
#
# where()(++select()+]#mul(916,868)
# )868,619(lum#]+)(tceles++()(erehw
# )868,619(lum
# final:  mul(916,868)
#
# }+>^-from()
# )(morf-^>+}
# )(m
# final:  m()
#
# }+>^-from()@mul(834,585)
# )585,438(lum@)(morf-^>+}
# )585,438(lum
# final:  mul(834,585)
#
# !]@what()
# )(tahw@]!
#
# !]@what()select()
# )(tceles)(tahw@]!
#
# !]@what()select()+#)
# )#+)(tceles)(tahw@]!
#
# !]@what()select()+#)/mul(722,165)
# )561,227(lum/)#+)(tceles)(tahw@]!
# )561,227(lum
# final:  mul(722,165)
#
# from()
# )(morf
# )(m
# final:  m()
#
# from()what()
# )(tahw)(morf
# )(tahw)(m
# final:  m()what()
#
# from()what()mul(220,639)
# )936,022(lum)(tahw)(morf
# )936,022(lum
# final:  mul(220,639)
#
# ^[[{$mul(738,370)
# )073,837(lum${[[^
# )073,837(lum
# final:  mul(738,370)
#
# $who()
# )(ohw$
#
# $who()who()
# )(ohw)(ohw$
#
# $who()who()<</ > >mul(650,822)
# )228,056(lum> > /<<)(ohw)(ohw$
# )228,056(lum
# final:  mul(650,822)
#
# )
# )
#
# ),/<,?when()
# )(nehw?,</,)
#
# ),/<,?when()mul(387,845)
# )548,783(lum)(nehw?,</,)
# )548,783(lum
# final:  mul(387,845)
#
# #from()
# )(morf#
# )(m
# final:  m()
#
# #from()&where()
# )(erehw&)(morf#
# )(erehw&)(m
# final:  m()&where()
#
# #from()&where()what()
# )(tahw)(erehw&)(morf#
# )(tahw)(erehw&)(m
# final:  m()&where()what()
#
# #from()&where()what(){mul(921,764)
# )467,129(lum{)(tahw)(erehw&)(morf#
# )467,129(lum
# final:  mul(921,764)
#
# ?from()
# )(morf?
# )(m
# final:  m()
#
# ?from()from()
# )(morf)(morf?
# )(m
# final:  m()
# )(m
# final:  m()
#
# ?from()from()do()
# )(od)(morf)(morf?
# )(od)(m
# final:  m()do()
# )(od)(m
# final:  m()do()
#
# ?from()from()do()>(;%~'mul(323,507)
# )705,323(lum'~%;(>)(od)(morf)(morf?
# )705,323(lum
# final:  mul(323,507)
#
# &}&#why()
# )(yhw#&}&
#
# &}&#why()when()
# )(nehw)(yhw#&}&
#
# &}&#why()when()who()
# )(ohw)(nehw)(yhw#&}&
#
# &}&#why()when()who()mul(998,500)
# )005,899(lum)(ohw)(nehw)(yhw#&}&
# )005,899(lum
# final:  mul(998,500)
#
# select()
# )(tceles
#
# select()[mul(543,802)
# )208,345(lum[)(tceles
# )208,345(lum
# final:  mul(543,802)
#
# from()
# )(morf
# )(m
# final:  m()
#
# from(){&?*/mul(809,888)
# )888,908(lum/*?&{)(morf
# )888,908(lum
# final:  mul(809,888)
#
# +',%[&when()
# )(nehw&[%,'+
#
# +',%[&when()$mul(909,660)
# )066,909(lum$)(nehw&[%,'+
# )066,909(lum
# final:  mul(909,660)
#
# do()
# )(od
#
# do(),:;)
# );:,)(od
#
# do(),:;)&>mul(303,499)
# )994,303(lum>&);:,)(od
# )994,303(lum
# final:  mul(303,499)
#
# when()
# )(nehw
#
# when()!where()
# )(erehw!)(nehw
#
# when()!where(){%what()
# )(tahw%{)(erehw!)(nehw
#
# when()!where(){%what()#mul(176,667)
# )766,671(lum#)(tahw%{)(erehw!)(nehw
# )766,671(lum
# final:  mul(176,667)
#
# &*mul(789,667)
# )766,987(lum*&
# )766,987(lum
# final:  mul(789,667)
#
# }*when()
# )(nehw*}
#
# }*when()/;how()
# )(woh;/)(nehw*}
#
# }*when()/;how()*when()
# )(nehw*)(woh;/)(nehw*}
#
# }*when()/;how()*when()mul(181,142)
# )241,181(lum)(nehw*)(woh;/)(nehw*}
# )241,181(lum
# final:  mul(181,142)
#
# how()
# )(woh
#
# how()what()
# )(tahw)(woh

# %%
# final check
print("mul word length: ", len(mul_words))
for m in mul_words:
    print(m)
# Out:
# mul word length:  700
# mul(929,350)
# mul(878,389)
# mul(786,950)
# mul(808,160)
# mul(659,500)
# mul(659,863)
# mul(281,23)
# mul(473,263)
# mul(208,697)
# mul(975,727)
# mul(862,420)
# mul(505,346)
# mul(150,525)
# mul(842,702)
# mul(669,360)
# mul(285,288)
# mul(778,743)
# mul(725,987)
# mul(757,125)
# mul(494,390)
# mul(182,852)
# mul(144,423)
# mul(250,580)
# mul(870,438)
# mul(965,381)
# mul(124,500)
# mul(307,602)
# mul(294,55)
# mul(466,143)
# mul(594,617)
# mul(590,187)
# mul(817,13)
# mul(25,13)
# mul(469,12)
# mul(619,597)
# mul(734,721)
# mul(725,524)
# mul(389,895)
# mul(166,39)
# mul(655,784)
# mul(353,573)
# mul(522,78)
# mul(236,646)
# mul(376,189)
# mul(300,957)
# mul(83,888)
# mul(107,58)
# mul(220,142)
# mul(526,112)
# mul(23,943)
# mul(338,718)
# mul(371,364)
# mul(856,727)
# mul(360,371)
# mul(664,647)
# mul(607,641)
# mul(395,603)
# mul(909,984)
# mul(271,246)
# mul(627,532)
# mul(229,147)
# mul(516,484)
# mul(897,791)
# mul(975,824)
# mul(861,612)
# mul(467,971)
# mul(351,45)
# mul(404,604)
# mul(821,895)
# mul(108,809)
# mul(107,714)
# mul(651,179)
# mul(421,625)
# mul(190,973)
# mul(532,234)
# mul(178,924)
# mul(258,345)
# mul(590,995)
# mul(563,305)
# mul(539,574)
# mul(493,590)
# mul(574,298)
# mul(213,273)
# mul(539,428)
# mul(289,634)
# mul(178,932)
# mul(535,222)
# mul(370,487)
# mul(228,11)
# mul(961,125)
# mul(489,332)
# mul(757,495)
# mul(814,931)
# mul(669,252)
# mul(69,754)
# mul(316,878)
# mul(772,418)
# mul(186,499)
# mul(517,805)
# mul(970,867)
# mul(739,456)
# mul(620,935)
# mul(715,502)
# mul(635,908)
# mul(30,139)
# mul(832,717)
# mul(518,190)
# mul(760,645)
# mul(835,464)
# mul(929,827)
# mul(838,387)
# mul(147,945)
# mul(689,161)
# mul(214,950)
# mul(165,90)
# mul(996,995)
# mul(347,352)
# mul(564,902)
# mul(515,489)
# mul(676,277)
# mul(243,328)
# mul(845,930)
# mul(696,341)
# mul(178,75)
# mul(531,586)
# mul(639,746)
# mul(501,62)
# mul(796,439)
# mul(766,409)
# mul(418,953)
# mul(435,11)
# mul(756,293)
# mul(598,25)
# mul(483,67)
# mul(116,813)
# mul(807,2)
# mul(982,63)
# mul(292,746)
# mul(20,251)
# mul(258,348)
# mul(570,47)
# mul(932,524)
# mul(939,325)
# mul(174,638)
# mul(180,359)
# mul(627,164)
# mul(445,389)
# mul(115,522)
# mul(516,970)
# mul(750,179)
# mul(393,378)
# mul(400,355)
# mul(606,611)
# mul(628,277)
# mul(570,862)
# mul(624,957)
# mul(946,45)
# mul(687,919)
# mul(839,726)
# mul(588,167)
# mul(503,12)
# mul(55,105)
# mul(349,994)
# mul(991,980)
# mul(313,17)
# mul(118,53)
# mul(276,699)
# mul(238,673)
# mul(40,718)
# mul(393,507)
# mul(715,497)
# mul(450,459)
# mul(570,625)
# mul(944,195)
# mul(203,571)
# mul(469,314)
# mul(839,867)
# mul(607,678)
# mul(733,382)
# mul(450,74)
# mul(139,672)
# mul(466,481)
# mul(474,988)
# mul(431,193)
# mul(587,948)
# mul(871,567)
# mul(974,456)
# mul(292,269)
# mul(507,563)
# mul(243,139)
# mul(212,698)
# mul(40,183)
# mul(362,950)
# mul(618,187)
# mul(504,988)
# mul(236,898)
# mul(285,955)
# mul(358,393)
# mul(676,462)
# mul(274,134)
# mul(895,912)
# mul(219,961)
# mul(481,864)
# mul(392,606)
# mul(920,948)
# mul(629,795)
# mul(645,709)
# mul(314,86)
# mul(74,407)
# mul(593,327)
# mul(411,974)
# mul(395,998)
# mul(989,530)
# mul(15,199)
# mul(816,920)
# mul(551,278)
# mul(863,732)
# mul(223,748)
# mul(474,54)
# mul(284,25)
# mul(374,334)
# mul(343,209)
# mul(952,521)
# mul(264,303)
# mul(984,690)
# mul(979,762)
# mul(387,945)
# mul(885,520)
# mul(950,716)
# mul(712,945)
# mul(83,500)
# mul(567,822)
# mul(877,379)
# mul(503,349)
# mul(961,381)
# mul(380,949)
# mul(261,613)
# mul(967,970)
# mul(587,914)
# mul(753,127)
# mul(292,235)
# mul(383,544)
# mul(272,707)
# mul(735,912)
# mul(62,107)
# mul(713,534)
# mul(572,504)
# mul(31,687)
# mul(313,607)
# mul(690,876)
# mul(273,373)
# mul(531,235)
# mul(111,213)
# mul(189,15)
# mul(964,850)
# mul(434,480)
# mul(579,808)
# mul(856,871)
# mul(900,159)
# mul(596,341)
# mul(455,990)
# mul(497,180)
# mul(613,543)
# mul(333,124)
# mul(545,512)
# mul(561,668)
# mul(478,75)
# mul(329,992)
# mul(241,743)
# mul(844,735)
# mul(966,882)
# mul(987,455)
# mul(515,519)
# mul(426,523)
# mul(460,572)
# mul(243,403)
# mul(632,748)
# mul(17,783)
# mul(713,921)
# mul(271,938)
# mul(511,239)
# mul(97,300)
# mul(237,42)
# mul(241,881)
# mul(907,680)
# mul(984,346)
# mul(210,168)
# mul(936,602)
# mul(818,741)
# mul(545,450)
# mul(844,400)
# mul(178,299)
# mul(47,387)
# mul(73,974)
# mul(722,711)
# mul(662,195)
# mul(928,541)
# mul(875,585)
# mul(699,625)
# mul(207,213)
# mul(604,342)
# mul(620,728)
# mul(135,593)
# mul(453,733)
# mul(645,243)
# mul(407,983)
# mul(932,718)
# mul(88,59)
# mul(123,691)
# mul(744,809)
# mul(213,965)
# mul(477,506)
# mul(701,848)
# mul(165,63)
# mul(399,533)
# mul(704,3)
# mul(694,548)
# mul(900,108)
# mul(774,475)
# mul(883,579)
# mul(923,647)
# mul(17,805)
# mul(326,383)
# mul(987,354)
# mul(639,894)
# mul(960,252)
# mul(609,294)
# mul(950,349)
# mul(290,391)
# mul(109,772)
# mul(335,149)
# mul(171,887)
# mul(807,659)
# mul(222,35)
# mul(671,994)
# mul(172,811)
# mul(76,532)
# mul(256,283)
# mul(882,66)
# mul(727,37)
# mul(753,604)
# mul(442,703)
# mul(451,658)
# mul(690,961)
# mul(409,762)
# mul(785,505)
# mul(181,733)
# mul(295,726)
# mul(261,933)
# mul(265,684)
# mul(912,21)
# mul(453,52)
# mul(566,994)
# mul(300,902)
# mul(136,86)
# mul(491,28)
# mul(267,97)
# mul(901,797)
# mul(11,309)
# mul(869,48)
# mul(342,192)
# mul(230,176)
# mul(587,59)
# mul(979,301)
# mul(651,625)
# mul(564,586)
# mul(686,200)
# mul(666,187)
# mul(788,793)
# mul(787,265)
# mul(111,927)
# mul(27,304)
# mul(176,110)
# mul(358,826)
# mul(501,531)
# mul(365,143)
# mul(759,671)
# mul(679,332)
# mul(817,808)
# mul(90,989)
# mul(503,769)
# mul(859,40)
# mul(638,143)
# mul(428,646)
# mul(320,540)
# mul(687,955)
# mul(602,820)
# mul(662,858)
# mul(691,924)
# mul(875,629)
# mul(338,859)
# mul(375,365)
# mul(336,223)
# mul(178,250)
# mul(984,814)
# mul(808,237)
# mul(194,593)
# mul(795,480)
# mul(749,71)
# mul(934,601)
# mul(807,763)
# mul(515,591)
# mul(499,662)
# mul(817,451)
# mul(306,889)
# mul(911,440)
# mul(886,109)
# mul(915,528)
# mul(144,716)
# mul(376,205)
# mul(274,491)
# mul(671,696)
# mul(375,359)
# mul(956,842)
# mul(618,693)
# mul(761,859)
# mul(542,515)
# mul(462,546)
# mul(660,240)
# mul(609,298)
# mul(279,293)
# mul(392,795)
# mul(128,643)
# mul(930,403)
# mul(933,726)
# mul(11,788)
# mul(442,615)
# mul(654,462)
# mul(960,246)
# mul(111,461)
# mul(641,83)
# mul(759,794)
# mul(543,856)
# mul(602,732)
# mul(124,738)
# mul(378,18)
# mul(723,701)
# mul(633,998)
# mul(833,630)
# mul(945,843)
# mul(705,202)
# mul(616,696)
# mul(163,194)
# mul(941,303)
# mul(924,715)
# mul(267,485)
# mul(526,75)
# mul(248,994)
# mul(985,752)
# mul(275,971)
# mul(592,347)
# mul(17,702)
# mul(800,427)
# mul(939,888)
# mul(143,267)
# mul(681,583)
# mul(656,683)
# mul(320,914)
# mul(345,44)
# mul(720,338)
# mul(265,100)
# mul(677,183)
# mul(525,84)
# mul(876,21)
# mul(344,65)
# mul(548,676)
# mul(833,540)
# mul(946,450)
# mul(753,627)
# mul(361,888)
# mul(700,949)
# mul(180,872)
# mul(882,985)
# mul(351,704)
# mul(764,860)
# mul(993,557)
# mul(56,860)
# mul(347,909)
# mul(699,230)
# mul(445,473)
# mul(267,398)
# mul(650,363)
# mul(601,997)
# mul(497,753)
# mul(141,967)
# mul(36,947)
# mul(681,450)
# mul(240,143)
# mul(444,949)
# mul(497,86)
# mul(430,567)
# mul(193,883)
# mul(689,168)
# mul(29,977)
# mul(205,284)
# mul(737,674)
# mul(12,767)
# mul(532,879)
# mul(765,185)
# mul(798,105)
# mul(332,180)
# mul(392,698)
# mul(436,468)
# mul(505,995)
# mul(890,215)
# mul(908,576)
# mul(714,969)
# mul(60,591)
# mul(792,423)
# mul(354,440)
# mul(713,525)
# mul(305,922)
# mul(448,877)
# mul(751,305)
# mul(179,695)
# mul(841,995)
# mul(353,537)
# mul(501,394)
# mul(999,635)
# mul(605,217)
# mul(936,501)
# mul(246,594)
# mul(256,918)
# mul(370,832)
# mul(925,451)
# mul(743,528)
# mul(815,611)
# mul(893,272)
# mul(687,268)
# mul(463,899)
# mul(56,377)
# mul(260,934)
# mul(945,828)
# mul(609,15)
# mul(287,981)
# mul(452,70)
# mul(836,664)
# mul(47,536)
# mul(694,750)
# mul(604,542)
# mul(632,9)
# mul(879,873)
# mul(632,382)
# mul(747,827)
# mul(697,54)
# mul(248,435)
# mul(258,340)
# mul(499,391)
# mul(409,16)
# mul(787,500)
# mul(643,861)
# mul(562,129)
# mul(577,258)
# mul(15,451)
# mul(981,70)
# mul(722,521)
# mul(123,277)
# mul(900,548)
# mul(148,194)
# mul(62,852)
# mul(61,450)
# mul(131,406)
# mul(909,412)
# mul(972,130)
# mul(222,940)
# mul(455,452)
# mul(8,457)
# mul(965,893)
# mul(787,423)
# mul(963,475)
# mul(81,905)
# mul(465,909)
# mul(534,596)
# mul(196,18)
# mul(27,285)
# mul(664,943)
# mul(813,372)
# mul(834,380)
# mul(813,509)
# mul(545,292)
# mul(708,344)
# mul(342,781)
# mul(117,146)
# mul(767,38)
# mul(24,562)
# mul(218,640)
# mul(108,530)
# mul(179,490)
# mul(33,386)
# mul(19,511)
# mul(541,350)
# mul(387,141)
# mul(238,338)
# mul(772,919)
# mul(429,335)
# mul(806,883)
# mul(175,190)
# mul(682,133)
# mul(846,821)
# mul(116,347)
# mul(924,51)
# mul(209,245)
# mul(460,178)
# mul(517,419)
# mul(68,998)
# mul(587,990)
# mul(765,879)
# mul(798,713)
# mul(739,10)
# mul(131,912)
# mul(825,581)
# mul(905,252)
# mul(863,782)
# mul(631,509)
# mul(930,251)
# mul(204,65)
# mul(231,133)
# mul(332,786)
# mul(726,913)
# mul(484,642)
# mul(590,989)
# mul(879,143)
# mul(498,143)
# mul(347,195)
# mul(930,586)
# mul(453,205)
# mul(75,857)
# mul(201,137)
# mul(861,373)
# mul(410,947)
# mul(106,316)
# mul(296,671)
# mul(481,274)
# mul(929,179)
# mul(29,898)
# mul(580,352)
# mul(585,530)
# mul(638,910)
# mul(894,636)
# mul(577,671)
# mul(999,788)
# mul(574,638)
# mul(66,674)
# mul(937,514)
# mul(750,907)
# mul(303,172)
# mul(15,812)
# mul(673,466)
# mul(623,971)
# mul(7,739)
# mul(509,601)
# mul(36,79)
# mul(199,611)
# mul(983,700)
# mul(136,594)
# mul(34,407)
# mul(71,117)
# mul(857,810)
# mul(993,232)
# mul(103,182)
# mul(607,926)
# mul(606,36)
# mul(756,418)
# mul(833,12)
# mul(74,614)
# mul(120,343)
# mul(714,187)
# mul(379,724)
# mul(5,213)
# mul(151,375)
# mul(34,537)
# mul(289,643)
# mul(938,238)
# mul(32,613)
# mul(415,379)
# mul(272,584)
# mul(164,981)
# mul(37,177)
# mul(527,858)
# mul(411,460)
# mul(628,434)
# mul(912,947)
# mul(279,831)
# mul(916,868)
# mul(834,585)
# mul(722,165)
# mul(220,639)
# mul(738,370)
# mul(650,822)
# mul(387,845)
# mul(921,764)
# mul(323,507)
# mul(998,500)
# mul(543,802)
# mul(809,888)
# mul(909,660)
# mul(303,499)
# mul(176,667)
# mul(789,667)
# mul(181,142)

# %%
mul_sets_multipled = []
for mul in mul_words:
    start_index = mul.find("(")
    end_index = mul.find(")")
    
    if start_index != -1 and end_index != -1:
        numbers = mul[start_index + 1:end_index]
        num_list = numbers.split(",")
        mul_sets_multipled.append(int(num_list[0])*int(num_list[1]))
        #print(numbers)

print(mul_sets_multipled)
# Out:
# [325150, 341542, 746700, 129280, 329500, 568717, 6463, 124399, 144976, 708825, 362040, 174730, 78750, 591084, 240840, 82080, 578054, 715575, 94625, 192660, 155064, 60912, 145000, 381060, 367665, 62000, 184814, 16170, 66638, 366498, 110330, 10621, 325, 5628, 369543, 529214, 379900, 348155, 6474, 513520, 202269, 40716, 152456, 71064, 287100, 73704, 6206, 31240, 58912, 21689, 242684, 135044, 622312, 133560, 429608, 389087, 238185, 894456, 66666, 333564, 33663, 249744, 709527, 803400, 526932, 453457, 15795, 244016, 734795, 87372, 76398, 116529, 263125, 184870, 124488, 164472, 89010, 587050, 171715, 309386, 290870, 171052, 58149, 230692, 183226, 165896, 118770, 180190, 2508, 120125, 162348, 374715, 757834, 168588, 52026, 277448, 322696, 92814, 416185, 840990, 336984, 579700, 358930, 576580, 4170, 596544, 98420, 490200, 387440, 768283, 324306, 138915, 110929, 203300, 14850, 991020, 122144, 508728, 251835, 187252, 79704, 785850, 237336, 13350, 311166, 476694, 31062, 349444, 313294, 398354, 4785, 221508, 14950, 32361, 94308, 1614, 61866, 217832, 5020, 89784, 26790, 488368, 305175, 111012, 64620, 102828, 173105, 60030, 500520, 134250, 148554, 142000, 370266, 173956, 491340, 597168, 42570, 631353, 609114, 98196, 6036, 5775, 346906, 971180, 5321, 6254, 192924, 160174, 28720, 199251, 355355, 206550, 356250, 184080, 115913, 147266, 727413, 411546, 280006, 33300, 93408, 224146, 468312, 83183, 556476, 493857, 444144, 78548, 285441, 33777, 147976, 7320, 343900, 115566, 497952, 211928, 272175, 140694, 312312, 36716, 816240, 210459, 415584, 237552, 872160, 500055, 457305, 27004, 30118, 193911, 400314, 394210, 524170, 2985, 750720, 153178, 631716, 166804, 25596, 7100, 124916, 71687, 495992, 79992, 678960, 745998, 365715, 460200, 680200, 672840, 41500, 466074, 332383, 175547, 366141, 360620, 159993, 937990, 536518, 95631, 68620, 208352, 192304, 670320, 6634, 380742, 288288, 21297, 189991, 604440, 101829, 124785, 23643, 2835, 819400, 208320, 467832, 745576, 143100, 203236, 450450, 89460, 332859, 41292, 279040, 374748, 35850, 326368, 179063, 620340, 852012, 449085, 267285, 222798, 263120, 97929, 472736, 13311, 656673, 254198, 122129, 29100, 9954, 212321, 616760, 340464, 35280, 563472, 606138, 245250, 337600, 53222, 18189, 71102, 513342, 129090, 502048, 511875, 436875, 44091, 206568, 451360, 80055, 332049, 156735, 400081, 669176, 5192, 84993, 601896, 205545, 241362, 594448, 10395, 212667, 2112, 380312, 97200, 367650, 511257, 597181, 13685, 124858, 349398, 571266, 241920, 179046, 331550, 113390, 84148, 49915, 151677, 531813, 7770, 666974, 139492, 40432, 72448, 58212, 26899, 454812, 310726, 296758, 663090, 311658, 396425, 132673, 214170, 243513, 181260, 19152, 23556, 562604, 270600, 11696, 13748, 25899, 718097, 3399, 41712, 65664, 40480, 34633, 294679, 406875, 330504, 137200, 124542, 624884, 208555, 102897, 8208, 19360, 295708, 266031, 52195, 509289, 225428, 660136, 89010, 386807, 34360, 91234, 276488, 172800, 656085, 493640, 567996, 638484, 550375, 290342, 136875, 74928, 44500, 800976, 191496, 115042, 381600, 53179, 561334, 615741, 304365, 330338, 368467, 272034, 400840, 96574, 483120, 103104, 77080, 134534, 467016, 134625, 804952, 428274, 653699, 279130, 252252, 158400, 181482, 81747, 311640, 82304, 374790, 677358, 8668, 271830, 302148, 236160, 51171, 53203, 602646, 464808, 440664, 91512, 6804, 506823, 631734, 524790, 796635, 142410, 428736, 31622, 285123, 660660, 129495, 39450, 246512, 740720, 267025, 205424, 11934, 341600, 833832, 38181, 397023, 448048, 292480, 15180, 243360, 26500, 123891, 44100, 18396, 22360, 370448, 449820, 425700, 472131, 320568, 664300, 156960, 868770, 247104, 657040, 553101, 48160, 315423, 160770, 210485, 106266, 235950, 599197, 374241, 136347, 34092, 306450, 34320, 421356, 42742, 243810, 170419, 115752, 28333, 58220, 496738, 9204, 467628, 141525, 83790, 59760, 273616, 204048, 502475, 191350, 523008, 691866, 35460, 335016, 155760, 374325, 281210, 392896, 229055, 124405, 836795, 189561, 197394, 634365, 131285, 468936, 146124, ...

# %%
print("total is ", sum(mul_sets_multipled))
# Out:
# total is  191183308
